# %%
import os,re
import requests as rq
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy

# %%
# make rappers from data folder
def get_rappers():
    
    def validate(name):
        # checks if the name has a
        illegal_chars = "|?:^*\""

        for c in illegal_chars:
            if c == '|':
                if name.find(c) > 0:
                    name = name.split("|")[1]
            if c == "\"":
                if name.find(c) > 0:
                    name = name.replace(r'"','',2)
            else: 
                name = name.replace(c,'')
        return name
    
    with open("data/rappers.txt", "r") as f:
        rappers = f.read()
        
    return [validate(rapper).strip() for rapper in rappers.split("\n")]
rappers = get_rappers()

# %%
import spotipy.oauth2 as oauth2

# When an error occurs saying the token expired, re-run this cell.
# Tokens are 1 hour I think.
client_id = 'e3344de9f0454df280cc34cdba040bf7'
client_secret = 'da09e980b2fb4f11a68a3c00a2669a7d'

credentials = oauth2.SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# %%
def get_uri(name, q_type):
    result = spotify.search(
        q='%s:%s' % (q_type, name), 
        type=q_type)[q_type+"s"]['items']

    
    # Make sure the 
    for i, x in enumerate(result):
        if x['name'].lower() == name.lower():
            return x['uri']

# %%
def get_albums(artist):
    artist_id = get_uri(artist.decode('utf-8'), 'artist')
    

    albums = spotify.artist_albums(artist_id, album_type='album')
    
    return set([album['name'] for album in albums['items']])

# %%
def get_album_info(album):
    info = {}
    
    album_id = get_uri(album,'album')
    try:
        album_info = spotify.album(album_id)
    except:
        raise Exception("Did not find album")
    try:
        song_info = spotify.album_tracks(album_id)
    except:
        raise Exception("Did not find album tracks")
    
    info['name'] = album_info['name']
    info['uri'] = album_info['uri']
    info['release_date'] = album_info['release_date']
    
    info['tracks'] = [{
        'track_title':track['name'],
        'uri':track['uri'],
        'collaborators':[artist['name'] for artist in track['artists']]}
        for track in song_info['items']]
    
    return info

# %%
get_uri('Aminé'.decode('utf-8'),'artist')
# Out:
# u'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'

# %%
spotify.search(q="artist:'Aminé'", type='artist')['artists']['items'][0]['uri']
# Out:
# u'spotify:artist:3Gm5F95VdRxW3mqCn8RPBJ'

# %%
get_discography("Aminé")
# Out:
# [{'name': u'ONEPOINTFIVE',
#   'release_date': u'2018-08-15',
#   'tracks': [{'collaborators': [u'Amin\xe9'],
#     'track_title': u'DR. WHOEVER',
#     'uri': u'spotify:track:2qpX5WY7A7uLLLQfFpvRDK'},
#    {'collaborators': [u'Amin\xe9', u'Gunna'],
#     'track_title': u'HICCUP (feat. Gunna)',
#     'uri': u'spotify:track:4TaGhbUWsmOWrQt8w3sA9x'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'REEL IT IN',
#     'uri': u'spotify:track:5qHirGR7M9tdm6C17DlzSY'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'BLACKJACK',
#     'uri': u'spotify:track:6U9OkV9oa8kN8LyBGf3wvJ'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'WHY?',
#     'uri': u'spotify:track:4qV3FpOX5NQbghsnmx3wKX'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'SHINE',
#     'uri': u'spotify:track:1OWGLpptXlHLw1yibeHiHa'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'CHINGY',
#     'uri': u'spotify:track:5KpUzmHFirESqWjCrXnmWS'},
#    {'collaborators': [u'Amin\xe9', u'G Herbo'],
#     'track_title': u'DAPPERDAN (feat. G Herbo)',
#     'uri': u'spotify:track:0iMIQ9pTAwimaR9gpUwOgo'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'CANTU',
#     'uri': u'spotify:track:3OzwuqlBU5IInWGKhIDhTq'},
#    {'collaborators': [u'Amin\xe9', u'Rico Nasty'],
#     'track_title': u'SUGARPARENTS (feat. Rico Nasty)',
#     'uri': u'spotify:track:2WS2N8wgs9Drd5MNJLJxkf'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'STFU2',
#     'uri': u'spotify:track:05tCaHe9yHLjO2qnXScDNV'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'RATCHET SATURN GIRL',
#     'uri': u'spotify:track:2q4F6OpQgx9umNB9uGFPYo'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'TOGETHER',
#     'uri': u'spotify:track:45WkcBtgPS8xulUwEg63X1'}],
#   'uri': u'spotify:album:4mwO9qIVmngSe7yR5Ios0I'},
#  {'name': u'Good For You',
#   'release_date': u'2017-07-28',
#   'tracks': [{'collaborators': [u'Amin\xe9', u'Ty Dolla $ign'],
#     'track_title': u'Veggies',
#     'uri': u'spotify:track:34yAAS72vZUXvsQPHGZexE'},
#    {'collaborators': [u'Amin\xe9', u'Nelly'],
#     'track_title': u'Yellow',
#     'uri': u'spotify:track:4Hj5yNHgu2dyrnzRQN7Gld'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Caroline',
#     'uri': u'spotify:track:5hTpBe8h35rJ67eAWHQsJx'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Hero',
#     'uri': u'spotify:track:7yQ2NWAIeDcIEauyVG5lck'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Spice Girl',
#     'uri': u'spotify:track:4HW5kSQ8M2IQWZhSxERvla'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'STFU',
#     'uri': u'spotify:track:4wlR30YY9mb1CsQkf9eoTP'},
#    {'collaborators': [u'Amin\xe9', u'Offset'],
#     'track_title': u'Wedding Crashers',
#     'uri': u'spotify:track:3nVDOYBJpdCkRR6r1DbZum'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Sundays',
#     'uri': u'spotify:track:2TLlFL6dpycifLqKtTE7UZ'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Turf',
#     'uri': u'spotify:track:6ODTw5ivAheWBql4tCiNkl'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Blinds',
#     'uri': u'spotify:track:366DLDHAnvMnHP5ECYt4N7'},
#    {'collaborators': [u'Amin\xe9', u'Charlie Wilson'],
#     'track_title': u'Dakota',
#     'uri': u'spotify:track:45oGS3iHeT2cvkihSP7KzK'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Slide',
#     'uri': u'spotify:track:0GS2K1xle0UpcAWa3u4BnG'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Money',
#     'uri': u'spotify:track:7sdqtgsO9zxvKdrrVDpaNu'},
#    {'collaborators': [u'Amin\xe9'],
#     'track_title': u'Beach Boy',
#     'uri': u'spotify:track:1jNyxG5S2P9gztbfAnrq85'},
#    {'collaborators': [u'Amin\xe9', u'Kehlani'],
#     'track_title': u'Heebiejeebies - Bonus',
#     'uri': u'spotify:track:32xx0fAv3CIeGmNaWTHvEF'}],
#   'uri': u'spotify:album:3lajefIuUk4SfzqVBSJy8p'}]

# %%
with open("data/abums/12341234.txt", "w") as f:
    f.write(get_discography("Aminé"))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-482-5155db72010b> in <module>()
# ----> 1 with open("data/abums/12341234.txt", "w") as f:
#       2     f.write(get_discography("Aminé"))
#
# IOError: [Errno 2] No such file or directory: 'data/abums/12341234.txt'

# %%
errors = []
for r in (rappers):
    try:
        with open('data/albums/%s.txt' % r.decode('utf-8')) as f:
            if len(f.read()) < 2:
                errors.append(r)
    except:
        print r
# Out:
# List of hip hop groups
# Lists of musicians

# %%
for e in errors:
    with open('data/albums/%s.txt' % r.encode('utf-8'), 'w') as f:
        f.write(str(get_discography(e)).encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-449-b22a6ffdb1bd> in <module>()
#       1 for e in errors:
#       2     with open('data/albums/%s.txt' % r.encode('utf-8'), 'w') as f:
# ----> 3         f.write(str(get_discography(e)).encode('utf-8'))
#
# <ipython-input-273-1cd92aaaefbb> in get_discography(artist)
#       1 def get_discography(artist):
#       2
# ----> 3     albums = get_albums(artist)
#       4
#       5     info = []
#
# <ipython-input-425-6e024fad0960> in get_albums(artist)
#       3
#       4
# ----> 5     albums = spotify.artist_albums(artist_id, album_type='album')
#       6
#       7     return set([album['name'] for album in albums['items']])
#
# C:\Users\allen\Anaconda2\lib\site-packages\spotipy\client.pyc in artist_albums(self, artist_id, album_type, country, limit, offset)
#     266         '''
#     267
# --> 268         trid = self._get_id('artist', artist_id)
#     269         return self._get('artists/' + trid + '/albums', album_type=album_type,
#     270                          country=country, limit=limit, offset=offset)
#
# C:\Users\allen\Anaconda2\lib\site-packages\spotipy\client.pyc in _get_id(self, type, id)
#     844
#     845     def _get_id(self, type, id):
# --> 846         fields = id.split(':')
#     847         if len(fields) >= 3:
#     848             if type != fields[-2]:
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
def get_discography(artist):
    
    albums = get_albums(artist)
    
    info = []
    
    for album in albums:
        try:
            info.append(get_album_info(album))
        except:
            continue
    return info

# %%
errors = []
for i,rapper in enumerate(rappers):
    with open("data/albums/%s.txt" % rapper.decode('utf-8'), "w") as f:
        try:
            print("======%d======" % i)
            f.write(str(get_discography(rapper)).encode('utf-8'))
        except AttributeError:
            print("====ERROR %d====" % i)
            errors.append((rapper,"AttributeError"))
            continue
        except IOError:
            print("====ERROR %d====" % i)
            errors.append((rapper, "IOError"))
# Out:
# ======0======
#     Getting uri for artist 03 Greedo
# Getting albums for 03 Greedo: spotify:artist:0FtsMKmZEq8fBWqdSOWtqp
#     Getting uri for album The Wolf of Grape Street
#     Getting uri for album God Level
#     Getting uri for album Purple Summer 2: Son Don't Shine
# ======1======
#     Getting uri for artist 100 Kila
# Getting albums for 100 Kila: spotify:artist:1eSLQvCYcfd5f1jgxBGbKJ
#     Getting uri for album ZLA10
# ======2======
#     Getting uri for artist 100s
# Getting albums for 100s: spotify:artist:7al781lgi4qF927X0fFVXj
#     Getting uri for album IVRY
#     Getting uri for album Ice Cold Perm
# ======3======
#     Getting uri for artist 12 Gauge
# Getting albums for 12 Gauge: spotify:artist:19dL0fni8Il6amPuGzxkmn
#     Getting uri for album 12 Gauge
#     Getting uri for album Da Shotgun Kid
# ======4======
#     Getting uri for artist 2 Chainz
# Getting albums for 2 Chainz: spotify:artist:17lzZA2AlOHwCwFALHttmp
#     Getting uri for album B.O.A.T.S. II #METIME (Deluxe)
#     Getting uri for album Tru Life
#     Getting uri for album Different World
#     Getting uri for album Pretty Girls Like Trap Music
#     Getting uri for album Daniel Son; Necklace Don
#     Getting uri for album Dope Peddler 2
# ERROR: Unable to find album info for Dope Peddler 2
#     Getting uri for album COLLEGROVE
#     Getting uri for album B.O.A.T.S. II #METIME
#     Getting uri for album TrapAvelli Tre
#     Getting uri for album Trap-a-Velli Tre
# ERROR: Unable to find album info for Trap-a-Velli Tre
# ======5======
#     Getting uri for artist 2 Pistols
# Getting albums for 2 Pistols: spotify:artist:7JBMlJmJpOk87BZTdbYSHD
#     Getting uri for album Death Before Dishonor
#     Getting uri for album J. Saunders Files
#     Getting uri for album Comin Back Hard
# ======6======
#     Getting uri for artist 2$ Fabo
# Getting albums for 2$ Fabo: spotify:artist:5rahJnED5dONBxuWjntRAj
# ======7======
#     Getting uri for artist 21 Savage
# Getting albums for 21 Savage: spotify:artist:1URnnhqYAYcrqrcwql10ft
#     Getting uri for album Savage Mode
#     Getting uri for album NOT ALL HEROES WEAR CAPES (Deluxe)
# ERROR: Unable to find album info for NOT ALL HEROES WEAR CAPES (Deluxe)
#     Getting uri for album Without Warning
#     Getting uri for album Issa Album
#     Getting uri for album The Slaughter Tape
#     Getting uri for album 21 UZI
# ERROR: Unable to find album info for 21 UZI
#     Getting uri for album Slaughter King
#     Getting uri for album 21 Gang
# ERROR: Unable to find album info for 21 Gang
# ======8======
#     Getting uri for artist 2Mex
# Getting albums for 2Mex: spotify:artist:49CSwy5keHWbZjeUrWyBmx
#     Getting uri for album B-Boys In Occupied Mexico
#     Getting uri for album 2Mex & Life Rexall Are $martyr
#     Getting uri for album B-Boys in Occupied Mexico
#     Getting uri for album Unreleased Hits
#     Getting uri for album My Fanbase Will Destroy You
# ======9======
#     Getting uri for artist 360
# Getting albums for 360: spotify:artist:3vn7rk7VNMfDhuZNB9sDYP
#     Getting uri for album Falling & Flying
#     Getting uri for album Falling & Flying (Clean)
# ERROR: Unable to find album info for Falling & Flying (Clean)
#     Getting uri for album Vintage Modern
#     Getting uri for album Falling & Flying (Platinum Edition)
# ERROR: Unable to find album info for Falling & Flying (Platinum Edition)
#     Getting uri for album UTOPIA
# ERROR: Unable to find album info for UTOPIA
#     Getting uri for album Utopia
#     Getting uri for album UTOPIA (Deluxe)
# ERROR: Unable to find album info for UTOPIA (Deluxe)
#     Getting uri for album UTOPIA (Clean)
# ERROR: Unable to find album info for UTOPIA (Clean)
#     Getting uri for album Falling and Flying
#     Getting uri for album What You See Is What You Get
# ======10======
#     Getting uri for artist 40 Glocc
# Getting albums for 40 Glocc: spotify:artist:4XEvTeo7w0M4EX2emvEpkX
#     Getting uri for album I Am Legend
#     Getting uri for album Graveyard Shift Hosted By DJ Drama
#     Getting uri for album COPS Cripin On Public Streets
#     Getting uri for album Outspoken3 (feat. DJ Strong & DJ Whoo Kid)
#     Getting uri for album Concrete Jungle
#     Getting uri for album Big Bad 4-0 New World Agenda
# ======11======
#     Getting uri for artist 50 Cent
# Getting albums for 50 Cent: spotify:artist:3q7HBObVc0L8jNeTe5Gofh
#     Getting uri for album Curtis
#     Getting uri for album Bullet Proof
#     Getting uri for album Before I Self-Destruct (Explicit Deluxe Version)
# ERROR: Unable to find album info for Before I Self-Destruct (Explicit Deluxe Version)
#     Getting uri for album Animal Ambition: An Untamed Desire To Win
#     Getting uri for album Before I Self-Destruct - The Selects
#     Getting uri for album Before I Self-Destruct
#     Getting uri for album Get Rich Or Die Tryin'
#     Getting uri for album The Massacre
# ======12======
#     Getting uri for artist 6ix9ine
# Getting albums for 6ix9ine: spotify:artist:7gZfnEnfiaHzxARJ2LeXrf
#     Getting uri for album Day69: Graduation Day
#     Getting uri for album DUMMY BOY
# ======13======
#     Getting uri for artist 6lack
# Getting albums for 6lack: None
# ====ERROR 13====
# ======14======
#     Getting uri for artist The 6th Letter
# Getting albums for The 6th Letter: spotify:artist:13xBRCVDFBBpq62dKRD6c8
#     Getting uri for album NorthernPlayalisticGetHighMuzik, Vol. 1
# ======15======
#     Getting uri for artist 9th Wonder
# Getting albums for 9th Wonder: spotify:artist:4s8ZGMVf3OiPktSP4ulpqU
#     Getting uri for album Zion
#     Getting uri for album The Final Adventure
#     Getting uri for album The Formula
#     Getting uri for album Indie 500
#     Getting uri for album The Solution
#     Getting uri for album 9th Wonder Presents Dream Merchant Volume 1
#     Getting uri for album Zion II
#     Getting uri for album The Dream Merchant 2
#     Getting uri for album Tutankhamen (Valley Of The Kings)
#     Getting uri for album The Wonder Years
#     Getting uri for album The Final Adventure (Instrumentals)
# ======16======
#     Getting uri for artist A+
# Getting albums for A+: spotify:artist:0QUIxJh1rw7FrbtvG6BbnA
#     Getting uri for album The Latch Key Child
#     Getting uri for album Class in Session
#     Getting uri for album Hempstead High
# ======17======
#     Getting uri for artist A-Q
# Getting albums for A-Q: spotify:artist:1KIUqtx5YIrGPv2JH7NRQF
# ======18======
#     Getting uri for artist Ab-Soul
# Getting albums for Ab-Soul: spotify:artist:0g9vAlRPK9Gt3FKCekk4TW
#     Getting uri for album Do What Thou Wilt.
#     Getting uri for album Longterm Mentality
#     Getting uri for album Control System
#     Getting uri for album These Days...
#     Getting uri for album Two Black Hippy
# ERROR: Unable to find album info for Two Black Hippy
# ======19======
#     Getting uri for artist A Boogie wit da Hoodie
# Getting albums for A Boogie wit da Hoodie: None
# ====ERROR 19====
# ======20======
#     Getting uri for artist Abstract Rude
# Getting albums for Abstract Rude: spotify:artist:7MnHRy1wlNojYiwYFJ8H7D
#     Getting uri for album The Owl's Cry
#     Getting uri for album Who Reframed the A-Team
#     Getting uri for album Rejuvenation
#     Getting uri for album Making Tracks
#     Getting uri for album Keep The Feel: a legacy of hip-hop soul
#     Getting uri for album AyeM Ray-Dio
#     Getting uri for album Lab Down Under
#     Getting uri for album Haiku De Theatre: The Best of Haiku De Tat
#     Getting uri for album Steel Making Tracks
#     Getting uri for album Making More Tracks
#     Getting uri for album Rejuvenation (Instrumentals)
#     Getting uri for album P.A.I.N.T.
#     Getting uri for album Dear Abbey, the Lost Letters Mixtape
#     Getting uri for album Showtyme!
#     Getting uri for album Kode Name Skorpius - The Best of CNS
#     Getting uri for album P.A.I.N.T. Instrumentals
#     Getting uri for album Showtyme! Instrumentals
# ======21======
#     Getting uri for artist Ace Hood
# Getting albums for Ace Hood: spotify:artist:31HjiqargV4NAw4GZqUale
#     Getting uri for album Starvation 5
#     Getting uri for album Starvation 4
#     Getting uri for album Trust the Process II: Undefeated
#     Getting uri for album Trials & Tribulations
#     Getting uri for album Braking the Bank
#     Getting uri for album Starvation 3
#     Getting uri for album Starvation 2
#     Getting uri for album The Statement 2
#     Getting uri for album Sex Chronicles (Hosted By Rosa Acosta)
# ERROR: Unable to find album info for Sex Chronicles (Hosted By Rosa Acosta)
#     Getting uri for album The Statement 2 (Coming Soon)
# ERROR: Unable to find album info for The Statement 2 (Coming Soon)
#     Getting uri for album Street Certified Banger
# ERROR: Unable to find album info for Street Certified Banger
#     Getting uri for album Body Bag 3 (Beast Mix)
# ERROR: Unable to find album info for Body Bag 3 (Beast Mix)
#     Getting uri for album The Final Warning (Mixtape)
# ERROR: Unable to find album info for The Final Warning (Mixtape)
#     Getting uri for album Trials & Tribulations (Deluxe)
#     Getting uri for album Starvation
#     Getting uri for album Trust the Process
# ======22======
#     Getting uri for artist Aceyalone
# Getting albums for Aceyalone: spotify:artist:7CaUk9xCxdXAmmqQn3PLR7
#     Getting uri for album Magnificent City
#     Getting uri for album Mars, Vol. 2
#     Getting uri for album Who Reframed the A-Team
#     Getting uri for album The Lonely Ones
#     Getting uri for album Action Accessed Remixes
#     Getting uri for album Ancient Future
#     Getting uri for album 43rd & Excellence
#     Getting uri for album Haiku De Theatre: The Best of Haiku De Tat
#     Getting uri for album All Balls Don't Bounce Revisited
#     Getting uri for album Lightning Strikes
#     Getting uri for album Grand Imperial
#     Getting uri for album Mars
# ERROR: Unable to find album info for Mars
#     Getting uri for album Leanin' on Slick
# ======23======
#     Getting uri for artist Action Bronson
# Getting albums for Action Bronson: spotify:artist:7BMccF0hQFBpP6417k1OtQ
#     Getting uri for album White Bronco
#     Getting uri for album Blue Chips 7000
#     Getting uri for album Well Done
#     Getting uri for album Mr. Wonderful
#     Getting uri for album SAAAB Stories produced by Harry Fraud
# ======24======
#     Getting uri for artist Adam Saleh
# Getting albums for Adam Saleh: spotify:artist:4i9TNpZ5lQbPWmMX4zvnNq
#     Getting uri for album Chapter II
# ======25======
#     Getting uri for artist Aesop Rock
# Getting albums for Aesop Rock: spotify:artist:2fSaE6BXtQy0x7R7v9IOmZ
#     Getting uri for album Labor Days
#     Getting uri for album The Impossible Kid
#     Getting uri for album The Impossible Kid (Instrumental Version)
#     Getting uri for album Float
#     Getting uri for album Daylight
#     Getting uri for album Skelethon
#     Getting uri for album None Shall Pass
#     Getting uri for album Skelethon (Instrumental Version)
#     Getting uri for album Bushwick (Original Motion Picture Soundtrack)
# ERROR: Unable to find album info for Bushwick (Original Motion Picture Soundtrack)
#     Getting uri for album Bazooka Tooth
#     Getting uri for album None Shall Pass (Bonus Edition)
#     Getting uri for album Fast Cars, Danger, Fire and Knives
#     Getting uri for album None Shall Pass - Instrumentals And Accapellas
#     Getting uri for album Skelethon [Deluxe Version]
# ======26======
#     Getting uri for artist Afrika Bambaataa
# Getting albums for Afrika Bambaataa: spotify:artist:7cg61q8kK8jlFi8TKKw70p
#     Getting uri for album Planet Rock '98
#     Getting uri for album Dark Matter Moving At The Speed Of Light
#     Getting uri for album Rhino Hi-Five: Afrika Bambaataa
#     Getting uri for album Planet Rock: The Dance Album
#     Getting uri for album Everyday People
#     Getting uri for album Beware (The Funk Is Everywhere)
#     Getting uri for album The Light
#     Getting uri for album Bring It Up
#     Getting uri for album Looking for the Perfect Beat 1980 -1985
# ERROR: Unable to find album info for Looking for the Perfect Beat 1980 -1985
#     Getting uri for album Zulu Groove
#     Getting uri for album Hydraulic Funk
#     Getting uri for album The Best of Afrika Bambaataa
# ERROR: Unable to find album info for The Best of Afrika Bambaataa
#     Getting uri for album Planet Rock: The Album
# ======27======
#     Getting uri for artist Afroman
# Getting albums for Afroman: spotify:artist:4Icvbp9RDt5aY2TWDOVDsr
#     Getting uri for album Greatest Hitz Live
#     Getting uri for album A Colt 45 Christmas
#     Getting uri for album Waiting to Inhale
#     Getting uri for album Marijuana Music
#     Getting uri for album The N-Word
#     Getting uri for album Drunk And High
#     Getting uri for album The Good Times
#     Getting uri for album Cold Fro-T-5 and Two Frigg Fraggs
#     Getting uri for album Happy to Be Alive
#     Getting uri for album Hungry Hustlerz, The: Starvation is Motivation
#     Getting uri for album Afroholic...The Even Better Times
#     Getting uri for album Afroholic (Clean Version)
#     Getting uri for album 4ro: 20
#     Getting uri for album The Frorider
# ======28======
#     Getting uri for artist Afu-Ra
# Getting albums for Afu-Ra: spotify:artist:6SWohEYYTym0RIBxvoh6wt
#     Getting uri for album Body of the Life Force 'pt. 2'
#     Getting uri for album Body Of The Life Force
#     Getting uri for album Life Force Radio
#     Getting uri for album State Of The Arts
# ======29======
#     Getting uri for artist Agallah
# Getting albums for Agallah: spotify:artist:4Ai7jlc9gCMBuiLYbjpIlw
#     Getting uri for album Bo: The Legend of the Water Dragon
#     Getting uri for album Club Hoppin' (12")
# ERROR: Unable to find album info for Club Hoppin' (12")
#     Getting uri for album You Already Know
#     Getting uri for album Agalito's Way
# ERROR: Unable to find album info for Agalito's Way
#     Getting uri for album The Red V
# ======30======
#     Getting uri for artist Ahmad
# Getting albums for Ahmad: None
# ====ERROR 30====
# ======31======
#     Getting uri for artist Ajs Nigrutin
# Getting albums for Ajs Nigrutin: spotify:artist:7EvkhWK1VWhOcMhMDeVpnV
#     Getting uri for album Fujznem džigili
#     Getting uri for album Fujznem Džigili
#     Getting uri for album Akupunktura Govneta
#     Getting uri for album Štrokavi pazuh
#     Getting uri for album Kajmak i katran
#     Getting uri for album Nigrutinski rečeno aka Štrokavi mozak
# ======32======
#     Getting uri for artist AKA_
# Getting albums for AKA_: None
# ====ERROR 32====
# ======33======
#     Getting uri for artist Akala
# Getting albums for Akala: spotify:artist:58LTO4K7E3WUtztMK2BCkB
#     Getting uri for album Acoustic Remixes
#     Getting uri for album The Thieves Banquet
#     Getting uri for album Doublethink
#     Getting uri for album 10 Years of Akala
#     Getting uri for album Knowledge Is Power, Vol. 2
#     Getting uri for album Freedom Lasso
#     Getting uri for album It's Not A Rumour
# ERROR: Unable to find album info for It's Not A Rumour
# ======34======
#     Getting uri for artist Akinyele
# Getting albums for Akinyele: spotify:artist:3P8PFi9LRirEf3JiEDOHZM
#     Getting uri for album Akinyele Live At The Barbecue - Unreleases Hit's
#     Getting uri for album Benny Ill
#     Getting uri for album Aktapuss
#     Getting uri for album Aktapuss (The Soundtrack)
#     Getting uri for album Vagina Diner
# ======35======
#     Getting uri for artist Akir
# Getting albums for Akir: spotify:artist:4OPwFSuypxZLw3ZL0Ei2UZ
#     Getting uri for album Street Edition Volumes 1&2
#     Getting uri for album The Secret
#     Getting uri for album Immortal Technique Presents: Akir
# ======36======
#     Getting uri for artist Akiva Schaffer
# Getting albums for Akiva Schaffer: None
# ====ERROR 36====
# ======37======
#     Getting uri for artist Akon
# Getting albums for Akon: spotify:artist:0z4gvV4rjIZ9wHck67ucSV
#     Getting uri for album Konvict Allstars
#     Getting uri for album Konkrete Jungle
#     Getting uri for album Freedom
#     Getting uri for album Freedom (Int'l Version 2)
# ERROR: Unable to find album info for Freedom (Int'l Version 2)
#     Getting uri for album KonKrete Jungle
#     Getting uri for album Koncrete Vol. 1
#     Getting uri for album Konvicted
#     Getting uri for album Trouble
# ======38======
#     Getting uri for artist The Alchemist
# Getting albums for The Alchemist: spotify:artist:0eVyjRhzZKke2KFYTcDkeu
#     Getting uri for album Bread
#     Getting uri for album Covert Coup Instrumentals
#     Getting uri for album Rapper's Best Friend 3: An Instrumental Series
# ERROR: Unable to find album info for Rapper's Best Friend 3: An Instrumental Series
#     Getting uri for album The Silent Partner (Instrumentals)
#     Getting uri for album The Alchemist & Oh No Present Welcome To Los Santos
# ERROR: Unable to find album info for The Alchemist & Oh No Present Welcome To Los Santos
#     Getting uri for album Retarded Alligator Beats
#     Getting uri for album Chemical Warfare
#     Getting uri for album Israeli Salad
#     Getting uri for album Moving Parts
#     Getting uri for album Rapper's Best Friend 2 (An Instrumental Series)
# ERROR: Unable to find album info for Rapper's Best Friend 2 (An Instrumental Series)
#     Getting uri for album The Good Book, Vol. 2
#     Getting uri for album Rapper's Best Friend 4: An Instrumental Series
# ERROR: Unable to find album info for Rapper's Best Friend 4: An Instrumental Series
#     Getting uri for album Russian Roulette
#     Getting uri for album The Cutting Room Floor 3
#     Getting uri for album Fetti
#     Getting uri for album Lunch Meat
#     Getting uri for album The Silent Partner
#     Getting uri for album Fantasy Island
# ======39======
#     Getting uri for artist Alex Wiley
# Getting albums for Alex Wiley: spotify:artist:0JdGPxHeRGfOyZg3EHwp2g
#     Getting uri for album Village Party
#     Getting uri for album Village Party 2: Heaven's Gate
#     Getting uri for album Club Wiley
#     Getting uri for album Village Party III: Stoner Symphony
#     Getting uri for album *one Singular Flame Emoji Ep*
#     Getting uri for album Tangerine Dream
#     Getting uri for album Synthia Part 1: Dial Tone
# ======40======
#     Getting uri for artist Ali Vegas
# Getting albums for Ali Vegas: spotify:artist:5dLUUj5dr2Ao0VpWKVf6Cg
#     Getting uri for album The New King 2
#     Getting uri for album P.T.O. 2
#     Getting uri for album Urban Wolves/Track Masters Presents...
#     Getting uri for album The Book of Ali
#     Getting uri for album The New King
# ERROR: Unable to find album info for The New King
#     Getting uri for album AutoVegography
#     Getting uri for album Just Let Me Rhyme
#     Getting uri for album Generation Gap 2: The Prequel
#     Getting uri for album Paid Time Off
# ======41======
#     Getting uri for artist AMG
# Getting albums for AMG: spotify:artist:66N53pjZxSlsUb8gxgmVvy
#     Getting uri for album Greatest Humps, Vol. One
#     Getting uri for album Bitch Betta Have My Money 2012
# ======42======
#     Getting uri for artist Amil
# Getting albums for Amil: spotify:artist:6NzM38IkXdbQsQ4qW9CG7z
#     Getting uri for album All Money Is Legal
#     Getting uri for album Tebi Za Ljubav
#     Getting uri for album Affetme
# ======43======
#     Getting uri for artist Aminé
# Getting albums for Aminé: None
# ====ERROR 43====
# ======44======
#     Getting uri for artist Amir Obè
# Getting albums for Amir Obè: None
# ====ERROR 44====
# ======45======
# C:\Users\allen\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if __name__ == '__main__':
#     Getting uri for artist Ampichino
# Getting albums for Ampichino: spotify:artist:04HECiWVE4ogBNdOvJuyps
#     Getting uri for album Mob Classicks
#     Getting uri for album Devilz Rejectz 3: American Horror Story
#     Getting uri for album Chasin' Chicken
#     Getting uri for album Chasin Chicken
#     Getting uri for album The Best of Traffic
#     Getting uri for album Stock Xchange
#     Getting uri for album Betrayal
#     Getting uri for album Featuring Ampichino
#     Getting uri for album Back 2 Back
# ERROR: Unable to find album info for Back 2 Back
#     Getting uri for album Cop Heavy Gang (Lost Work)
#     Getting uri for album The Usual Suspects
#     Getting uri for album Dead Presidents (Remastered)
#     Getting uri for album Interstate Amp
#     Getting uri for album Stock Exchange
#     Getting uri for album Lost Sessions
#     Getting uri for album Dead Presidents 2
#     Getting uri for album Dope Dealers Emporium
#     Getting uri for album D.D.E.
# ======46======
#     Getting uri for artist Anderson .Paak
# Getting albums for Anderson .Paak: spotify:artist:3jK9MiCrA42lLAdMGUZpwa
#     Getting uri for album Venice
#     Getting uri for album Yes Lawd!
#     Getting uri for album Yes Lawd! Remixes
#     Getting uri for album Malibu
#     Getting uri for album Oxnard
# ======47======
#     Getting uri for artist André 3000
# Getting albums for André 3000: None
# ====ERROR 47====
# ======48======
#     Getting uri for artist Andre Nickatina
# Getting albums for Andre Nickatina: spotify:artist:7boQqq2hUcz9kHcQOecG4j
#     Getting uri for album Booty Star- Glock Tawk
#     Getting uri for album The King and Mr. Biscuits
#     Getting uri for album Hells Kitchen
#     Getting uri for album Tears Of A Clown
#     Getting uri for album Raven Cocaine Raps Vol 1.
#     Getting uri for album A Tale Of Two Andres
#     Getting uri for album Conversation With A Devil
#     Getting uri for album These R the Tales
#     Getting uri for album Daiquiri Factory Cocaine Raps Volume 2
#     Getting uri for album The Best Of 2011
#     Getting uri for album Ugly Money 2 - Love It and Count It
#     Getting uri for album Cocaine Inc (Cocaine Raps 1, 2, & 3)
#     Getting uri for album Midnight Machine Gun Rhymes And Alibis
#     Getting uri for album Pisces
#     Getting uri for album Khanthology
#     Getting uri for album KHAN! The Me Generation
#     Getting uri for album Bullets, Blunts, n ah Big Bank Roll
#     Getting uri for album I Hate You With A Passion
#     Getting uri for album Andre Nickatina
# ======49======
#     Getting uri for artist Andy Mineo
# Getting albums for Andy Mineo: spotify:artist:1TMrnxBwZfmfRxsGzkNIHw
#     Getting uri for album Andy Mineo and Wordsplayed present Magic & Bird
#     Getting uri for album Formerly Known
#     Getting uri for album Uncomfortable
#     Getting uri for album II: The Sword
#     Getting uri for album Heroes for Sale
#     Getting uri for album Uncomfortable (Commentary)
# ======50======
#     Getting uri for artist Andy Samberg
# Getting albums for Andy Samberg: None
# ====ERROR 50====
# ======51======
#     Getting uri for artist Angel Haze
# Getting albums for Angel Haze: spotify:artist:2cyyGl4qnHZL0o16t0fpJl
#     Getting uri for album Dirty Gold
#     Getting uri for album Reservation
#     Getting uri for album Dirty Gold (Deluxe)
#     Getting uri for album Back to the Woods
#     Getting uri for album Dirty Gold (Track By Track)
# ERROR: Unable to find album info for Dirty Gold (Track By Track)
# ======52======
#     Getting uri for artist Angie Martinez
# Getting albums for Angie Martinez: spotify:artist:6VJqy1YyzrK4ZhgGs9cNTy
# ======53======
#     Getting uri for artist Ant
# Getting albums for Ant: None
# ====ERROR 53====
# ======54======
#     Getting uri for artist Ant Banks
# Getting albums for Ant Banks: spotify:artist:6KnIBNJz25ik5sGjtvYFEi
#     Getting uri for album The Best Of Ant Banks
#     Getting uri for album Back to the Money Mixtpae
#     Getting uri for album Big Badass
#     Getting uri for album Ant Banks Presents TWDY Derty Werk
#     Getting uri for album Ant Banks Presents TWDY Derty Werk (Explicit)
# ERROR: Unable to find album info for Ant Banks Presents TWDY Derty Werk (Explicit)
#     Getting uri for album Do Or Die
#     Getting uri for album Big Thangs
# ======55======
#     Getting uri for artist Anthony Parker
# Getting albums for Anthony Parker: None
# ====ERROR 55====
# ======56======
#     Getting uri for artist Antoinette
# Getting albums for Antoinette: spotify:artist:1YMUQTkHnsU6HKFUTLSxZ4
# ======57======
#     Getting uri for artist Anybody Killa
# Getting albums for Anybody Killa: None
# ====ERROR 57====
# ======58======
#     Getting uri for artist Apache
# Getting albums for Apache: spotify:artist:2pvyE8W9RWESQxkyAWZqgY
#     Getting uri for album Lo Necesario
#     Getting uri for album Sin Afina' mucho
#     Getting uri for album Original Combination
#     Getting uri for album Ahora O Nunca
#     Getting uri for album Afinando
# ======59======
#     Getting uri for artist Apathy
# Getting albums for Apathy: spotify:artist:6fK2hnSgfRPxR6sL975XQS
#     Getting uri for album No Place Like Chrome
#     Getting uri for album The Black Lodge
#     Getting uri for album Wanna Snuggle?
#     Getting uri for album Fire Walk with Me: It's the Bootleg, Muthafuckas! Vol. 3
#     Getting uri for album Handshakes with Snakes
#     Getting uri for album Honkey Kong (Instrumentals)
#     Getting uri for album Weekend at the Cape (Instrumentals + Acapellas)
#     Getting uri for album Uzi Does It
#     Getting uri for album Connecticut Casual
#     Getting uri for album The Widow's Son
#     Getting uri for album Weekend at the Cape
#     Getting uri for album The Alien Tongue
#     Getting uri for album Honkey Kong
#     Getting uri for album Handshakes with Snakes (Instrumentals + Acapellas)
#     Getting uri for album Wanna Snuggle? (Instrumentals)
#     Getting uri for album Perestroika
#     Getting uri for album Dive Medicine: Chapter One (Instrumental Project)
#     Getting uri for album Perestroika (Instrumentals + Acapellas)
#     Getting uri for album The Widow's Son (Instrumentals + Acapellas)
#     Getting uri for album Connecticut Casual (Instrumentals + Acapellas)
# ======60======
#     Getting uri for artist Arabian Prince
# Getting albums for Arabian Prince: spotify:artist:5NMN8ahOjFuRoyYVjKGFGq
#     Getting uri for album Innovative Life
# ======61======
#     Getting uri for artist Arin Hanson
# Getting albums for Arin Hanson: spotify:artist:6tC4njgw0jeDWSkOZlI4yL
# ======62======
#     Getting uri for artist A$AP Ferg
# Getting albums for A$AP Ferg: spotify:artist:5dHt1vcEm9qb8fCyLcB3HL
#     Getting uri for album ALWAYS STRIVE AND PROSPER
#     Getting uri for album Still Striving
#     Getting uri for album Trap Lord
# ======63======
#     Getting uri for artist A$AP Nast
# Getting albums for A$AP Nast: spotify:artist:1uLYUm2A6kpFYAECfAFoH1
# ======64======
#     Getting uri for artist A$AP Rocky
# Getting albums for A$AP Rocky: spotify:artist:13ubrt8QOOCPljQ2FL1Kca
#     Getting uri for album AT.LONG.LAST.A$AP
#     Getting uri for album LONG.LIVE.A$AP (Deluxe Version)
#     Getting uri for album TESTING
#     Getting uri for album LONG.LIVE.A$AP
# ======65======
#     Getting uri for artist A$AP Yams
# Getting albums for A$AP Yams: spotify:artist:0KhmBcHGjrDVtCdrH0tQTu
# ======66======
#     Getting uri for artist A$ton Matthews
# Getting albums for A$ton Matthews: None
# ====ERROR 66====
# ======67======
#     Getting uri for artist Asher Roth
# Getting albums for Asher Roth: spotify:artist:1wgY8huggK60P5nvYrwcYT
#     Getting uri for album Pabst & Jazz
#     Getting uri for album Asleep In The Bread Aisle (UK Version)
# ERROR: Unable to find album info for Asleep In The Bread Aisle (UK Version)
#     Getting uri for album Asleep In The Bread Aisle
#     Getting uri for album Retrohash
# ERROR: Unable to find album info for Retrohash
#     Getting uri for album RAWTHER
#     Getting uri for album RetroHash
# ======68======
#     Getting uri for artist Astronautalis
# Getting albums for Astronautalis: spotify:artist:6PWRJs1FosHp8Cqx0Nmswj
#     Getting uri for album Pomegranate
#     Getting uri for album 6666
#     Getting uri for album The Mighty Ocean and Nine Dark Theaters
#     Getting uri for album You and Yer Good Ideas
#     Getting uri for album This Is Our Science
#     Getting uri for album Sike!
#     Getting uri for album Cut The Body Loose
#     Getting uri for album Cut the Body Loose
# ======69======
#     Getting uri for artist Awol One
# Getting albums for Awol One: spotify:artist:11xoGH8177GQvn06RB5HIx
# ======70======
#     Getting uri for artist Awkwafina
# Getting albums for Awkwafina: spotify:artist:3SmyWs7ou3udD8gtM0Z6Vx
#     Getting uri for album Yellow Ranger
#     Getting uri for album In Fina We Trust
# ======71======
#     Getting uri for artist AZ
# Getting albums for AZ: spotify:artist:7HqrSDuI9lHuH1CDismTFg
#     Getting uri for album 9 Lives
#     Getting uri for album Undeniable
#     Getting uri for album Pieces Of A Man
#     Getting uri for album Doe Or Die
#     Getting uri for album The Format (Special Edition)
#     Getting uri for album Final Call
#     Getting uri for album N 4 L
#     Getting uri for album Legendary
#     Getting uri for album G.O.D. (Gold, Oil & Diamonds)
#     Getting uri for album Aziatic
#     Getting uri for album A.W.O.L.
#     Getting uri for album Doe or Die 15th Anniversary
# ======72======
#     Getting uri for artist Azealia Banks
# Getting albums for Azealia Banks: spotify:artist:7gRhy3MIPHQo5CXYfWaw9I
#     Getting uri for album Slay-Z
#     Getting uri for album Fantasea
#     Getting uri for album Broke With Expensive Taste
# ERROR: Unable to find album info for Broke With Expensive Taste
#     Getting uri for album Broke with Expensive Taste
# ======73======
#     Getting uri for artist B-Legit
# Getting albums for B-Legit: spotify:artist:6nltEpEZtqZD1v4YJLlaZI
#     Getting uri for album Connected And Respected
#     Getting uri for album Connected and Respected
#     Getting uri for album Block Movement (Explicit Version)
#     Getting uri for album Hard 2 B-legit
#     Getting uri for album Bay Area Playas 5: The New Breeds
#     Getting uri for album Tryin' To Get A Buck
#     Getting uri for album Game Is To Be Sold
#     Getting uri for album The Hemp Museum
#     Getting uri for album Block Movement
#     Getting uri for album Hempin
#     Getting uri for album What We Been Doin
#     Getting uri for album Tryin' To Get A Back
#     Getting uri for album Block Movement - 100% Savage
# ======74======
#     Getting uri for artist B-Real
# Getting albums for B-Real: spotify:artist:2LiWxiQzuD9nmWQ6NCA8Gd
#     Getting uri for album The Harvest: Vol.1
#     Getting uri for album The Prescription
#     Getting uri for album Prohibition Part 2
#     Getting uri for album Serial Killers: Day of the Dead
#     Getting uri for album Prohibition
#     Getting uri for album Smoke N Mirrors
#     Getting uri for album Prohibition, Pt. 3
#     Getting uri for album The Gunslinger, Pt. II: Fist Full of Dollars
#     Getting uri for album Smoke N Mirrors (Clean)
# ERROR: Unable to find album info for Smoke N Mirrors (Clean)
# ======75======
#     Getting uri for artist B.G.
# Getting albums for B.G.: spotify:artist:36HvjE9pV91jEjO1qBRidS
#     Getting uri for album 404 User Not Found
#     Getting uri for album We Got This
#     Getting uri for album Champion
#     Getting uri for album The Heart Of Tha Streetz - Volume 2
#     Getting uri for album Livin Legend
#     Getting uri for album Hood Generals
#     Getting uri for album Life After Cash Money
#     Getting uri for album The Heart Of Tha Street
#     Getting uri for album Connected
#     Getting uri for album 80's Babies
# ERROR: Unable to find album info for 80's Babies
#     Getting uri for album Hollyhood
#     Getting uri for album Thug Brothers
#     Getting uri for album Too Hood 2 Be Hollywood
# ======76======
#     Getting uri for artist B.G. Knocc Out
# Getting albums for B.G. Knocc Out: spotify:artist:0gwtYWiJ1xK3wfDvkEWwad
#     Getting uri for album Features
#     Getting uri for album Da New Crip
#     Getting uri for album St.L.a.
#     Getting uri for album Uncommom
#     Getting uri for album Eazy E's Protege
#     Getting uri for album 1-Up
# ERROR: Unable to find album info for 1-Up
#     Getting uri for album Real Brothers
#     Getting uri for album 5st. (Regime Change)
#     Getting uri for album Blocc Boyz
# ======77======
#     Getting uri for artist B.o.B
# Getting albums for B.o.B: spotify:artist:5ndkK3dpZLKtBklKjxNQwT
#     Getting uri for album The Upside Down
#     Getting uri for album Strange Clouds
#     Getting uri for album Elements
#     Getting uri for album Underground Luxury
#     Getting uri for album EPIC: Every Play Is Crucial
#     Getting uri for album Psycadelik Thoughtz
#     Getting uri for album Cloud 9
#     Getting uri for album B.o.B Presents: The Adventures of Bobby Ray
#     Getting uri for album No Genre 2
#     Getting uri for album Fuck Em We Ball
#     Getting uri for album NAGA
#     Getting uri for album No Genre
#     Getting uri for album Ether
#     Getting uri for album New Black
# ======78======
#     Getting uri for artist Baby Bash
# Getting albums for Baby Bash: spotify:artist:12PSlydMSjEHzSCj9X5qv7
#     Getting uri for album The Legalizers: Legalize or Die, Vol. 1
#     Getting uri for album Unsung The Album
#     Getting uri for album Get Wiggy
#     Getting uri for album So Quick... Like A Heist
#     Getting uri for album Sangria
#     Getting uri for album M.S.U.
#     Getting uri for album Mènage A Trois
# ERROR: Unable to find album info for Mènage A Trois
#     Getting uri for album Ronnie Rey All Day
#     Getting uri for album Playamade Mexicanz (Chopped Not Slopped)
#     Getting uri for album Playamade Mexicanz II
#     Getting uri for album Cyclone
#     Getting uri for album Bashtown
#     Getting uri for album The Legalizers, Vol. 2: Indoor Grow
#     Getting uri for album Bashtown (Explicit)
#     Getting uri for album Playamade Mexicanz
#     Getting uri for album Don't Panic It's Organic
# ERROR: Unable to find album info for Don't Panic It's Organic
# ======79======
#     Getting uri for artist Baby Boy da Prince
# Getting albums for Baby Boy da Prince: None
# ====ERROR 79====
# ======80======
#     Getting uri for artist Baby D
# Getting albums for Baby D: spotify:artist:33ZOI0WTjYkLh5WuwucLhc
# ======81======
#     Getting uri for artist Bad Azz
# Getting albums for Bad Azz: spotify:artist:1ykdy4jtPLFOuaJrZqHTbp
#     Getting uri for album The Nu Adventures Of Bad Azz
#     Getting uri for album Money Run
#     Getting uri for album Word On Tha Streets
#     Getting uri for album Executive Decision (Business. Nothing Personal)
#     Getting uri for album Thug Pound
#     Getting uri for album Personal Business
# ======82======
#     Getting uri for artist Badshah
# Getting albums for Badshah: spotify:artist:0y59o4v8uw5crbN9M3JiL1
#     Getting uri for album Namaste England (Original Motion Picture Soundtrack)
# ERROR: Unable to find album info for Namaste England (Original Motion Picture Soundtrack)
#     Getting uri for album The Badshah of Party Hits
#     Getting uri for album ONE (Original Never Ends)
# ======83======
#     Getting uri for artist Baeza
# Getting albums for Baeza: spotify:artist:0g7YfJuAQnXWMiFny5elRH
#     Getting uri for album 24
#     Getting uri for album Dough and Dro
#     Getting uri for album The Man
# ERROR: Unable to find album info for The Man
#     Getting uri for album Stuck in My Ways
# ======84======
#     Getting uri for artist Bahamadia
# Getting albums for Bahamadia: spotify:artist:6ZcRUVs3I5U8EOnm9ZdCsO
#     Getting uri for album Kollage
#     Getting uri for album BB Queen
#     Getting uri for album Good Rap Music
# ======85======
#     Getting uri for artist Baka Not Nice
# Getting albums for Baka Not Nice: spotify:artist:3yvCFkK57FXH7JIwZQ5CmU
#     Getting uri for album 4Milli
# ======86======
#     Getting uri for artist Bang Yong-guk
# Getting albums for Bang Yong-guk: None
# ====ERROR 86====
# ======87======
#     Getting uri for artist Bangladesh
# Getting albums for Bangladesh: spotify:artist:3z8lWUpLUM0Z4b2184qpQF
# ======88======
#     Getting uri for artist Bas
# Getting albums for Bas: spotify:artist:70gP6Ry4Uo0Yx6uzPIdaiJ
#     Getting uri for album Last Winter
#     Getting uri for album Milky Way
#     Getting uri for album Too High To Riot
# ======89======
#     Getting uri for artist Battlecat
# Getting albums for Battlecat: spotify:artist:2W7vXpIPRDkFiYOy8dCvZe
# ======90======
#     Getting uri for artist Beanie Sigel
# Getting albums for Beanie Sigel: spotify:artist:0tCtGc5vt29zFZp6KXzN50
#     Getting uri for album The Broad Street Bully
#     Getting uri for album The Solution [Exclusive Edition (Explicit)]
# ERROR: Unable to find album info for The Solution [Exclusive Edition (Explicit)]
#     Getting uri for album This Time
#     Getting uri for album The Roc Boys
#     Getting uri for album The Truth
#     Getting uri for album The B.Coming
#     Getting uri for album In Beans We Trust
#     Getting uri for album The Solution
#     Getting uri for album The Solution [Exclusive Edition (Edited)]
# ERROR: Unable to find album info for The Solution [Exclusive Edition (Edited)]
#     Getting uri for album Untagged
#     Getting uri for album The Reason
# ======91======
#     Getting uri for artist Becky G
# Getting albums for Becky G: spotify:artist:4obzFoKoKRHIphyHzJ35G3
# ======92======
#     Getting uri for artist Benny Blanco
# Getting albums for Benny Blanco: spotify:artist:18lVbIzwvArI6wXtF09Mwh
# ======93======
#     Getting uri for artist Beenzino
# Getting albums for Beenzino: spotify:artist:7IrDIIq3j04exsiF3Z7CPg
#     Getting uri for album 12
#     Getting uri for album 24: 26 (5th Anniversary Remaster Edition)
#     Getting uri for album 24:26 (5th Anniversary Remaster Edition)
# ======94======
#     Getting uri for artist Benzino
# Getting albums for Benzino: spotify:artist:4kL2OPLMiNMXhojqQSNkUQ
#     Getting uri for album The Benzino Project
#     Getting uri for album Redemption
# ======95======
#     Getting uri for artist BewhY
# Getting albums for BewhY: spotify:artist:1wsoV3RXPkxVz3PwsNRI5K
#     Getting uri for album The Blind Star
# ======96======
#     Getting uri for artist Bhad Bhabie
# Getting albums for Bhad Bhabie: spotify:artist:7DuTB6wdzqFJGFLSH17k8e
#     Getting uri for album 15
# ======97======
#     Getting uri for artist Big Boi
# Getting albums for Big Boi: spotify:artist:2ht3wxeT69CzyKFChNnNAB
#     Getting uri for album Sir Lucious Left Foot...The Son Of Chico Dusty
#     Getting uri for album Big Boi Presents…Got Purp?
#     Getting uri for album Vicious Lies and Dangerous Rumors
#     Getting uri for album Sir Lucious Left Foot...The Son Of Chico Dusty (Deluxe)
#     Getting uri for album BOOMIVERSE
#     Getting uri for album Vicious Lies and Dangerous Rumors (Deluxe)
#     Getting uri for album Big Boi Presents... Got Purp? Vol. 2
# ======98======
#     Getting uri for artist Big Daddy Kane
# Getting albums for Big Daddy Kane: spotify:artist:6futYSDVulYR2PktBjTB5W
#     Getting uri for album Looks Like A Job For...
#     Getting uri for album Ain't No Half-Steppin'
# ERROR: Unable to find album info for Ain't No Half-Steppin'
#     Getting uri for album Long Live The Kane
#     Getting uri for album Daddy's Home
# ERROR: Unable to find album info for Daddy's Home
#     Getting uri for album The Power of Music
#     Getting uri for album Veteranz Day
#     Getting uri for album It's A Big Daddy Thing
# ERROR: Unable to find album info for It's A Big Daddy Thing
#     Getting uri for album Taste Of Chocolate
# ======99======
#     Getting uri for artist Big Ed
# Getting albums for Big Ed: spotify:artist:6umPCSfYWO6G8gh3A8opJ5
#     Getting uri for album Special Forces
# ======100======
#     Getting uri for artist Big Gipp
# Getting albums for Big Gipp: spotify:artist:7e36DF0IaZI4JXfIf95ppT
#     Getting uri for album Mutant Mindframe
# ======101======
#     Getting uri for artist Big Hawk
# Getting albums for Big Hawk: spotify:artist:5UZLYxzCWbloCIsXVq59gT
# ======102======
#     Getting uri for artist Big K.R.I.T.
# Getting albums for Big K.R.I.T.: spotify:artist:0CKa42Jqrc9fSFbDjePaXP
#     Getting uri for album 4eva Is A Mighty Long Time
#     Getting uri for album Cadillactica
#     Getting uri for album Live From The Underground
#     Getting uri for album All My Life
#     Getting uri for album Cadillactica (Deluxe)
# ======103======
#     Getting uri for artist Big Kuntry King
# Getting albums for Big Kuntry King: spotify:artist:4V77E8MyGPCCvvjVFbYQfS
#     Getting uri for album Cocaine Kuntry: The Underboss
#     Getting uri for album My Turn To Eat
#     Getting uri for album 100% (KANE)
#     Getting uri for album Perignon Don
# ======104======
#     Getting uri for artist Big L
# Getting albums for Big L: spotify:artist:30fiiwr2EeZp1tAhzYCmyM
#     Getting uri for album Return of the Devil's Son (Deluxe Edition)
#     Getting uri for album Lifestylez Ov Da Poor & Dangerous
#     Getting uri for album The Danger Zone
#     Getting uri for album The Big Picture
#     Getting uri for album L Corleone
#     Getting uri for album The Danger Zone: Deluxe Edition
# ======105======
#     Getting uri for artist Big Lurch
# Getting albums for Big Lurch: spotify:artist:2bbZruE5XNEEQEUxajPb3D
#     Getting uri for album Already, Vol. 1
#     Getting uri for album Already, Vol. 2
#     Getting uri for album Already, Vol. 3
#     Getting uri for album Mood Swings, Vol.1
#     Getting uri for album It's All Bad
# ERROR: Unable to find album info for It's All Bad
# ======106======
#     Getting uri for artist Big Mello
# Getting albums for Big Mello: spotify:artist:7cTUKWe96m3QwHMkDPnw8l
#     Getting uri for album Bone Hard Zaggin
#     Getting uri for album Wegonefunkwichamind (Screwed)
#     Getting uri for album Wegonefunkwichamind
#     Getting uri for album Bone Hard Zaggin (Screwed)
#     Getting uri for album Southside Story
#     Getting uri for album The Gift : Slowed
#     Getting uri for album The Gift
#     Getting uri for album Done Deal
# ======107======
#     Getting uri for artist Big Mike
# Getting albums for Big Mike: spotify:artist:2NeBwEmM7I71IsGl1y6FG0
#     Getting uri for album Still Serious
#     Getting uri for album Fast Boy Music
#     Getting uri for album Bayou Classic - Love.Faith.Honor.Loyalty
#     Getting uri for album O.G. Big Mike
#     Getting uri for album Bonus Tracks
# ERROR: Unable to find album info for Bonus Tracks
#     Getting uri for album Ridah Music Vol.1 (The Invitation)
#     Getting uri for album Hard to Hit
#     Getting uri for album State of Mind
#     Getting uri for album Apply Pressure 2
# ======108======
#     Getting uri for artist Big Moe
# Getting albums for Big Moe: spotify:artist:4Yj490bi1KL0QpDnVOtHyr
#     Getting uri for album Forever Moe
#     Getting uri for album Moe Life: Swishahouse Chopped & Skrewed
#     Getting uri for album Unfinished Business
#     Getting uri for album City of Syrup (Chopped & Screwed Version)
#     Getting uri for album Classics Vol. 1
# ERROR: Unable to find album info for Classics Vol. 1
#     Getting uri for album Moe Life
#     Getting uri for album City of Syrup
#     Getting uri for album City Of Syrup
#     Getting uri for album Purple World
#     Getting uri for album Moe Life: Chopped & Skrewed (Chopped & Screwed Version)
#     Getting uri for album Classics, Vol. 1
#     Getting uri for album City Of Syrup : Screwed
# ======109======
#     Getting uri for artist Big Noyd
# Getting albums for Big Noyd: spotify:artist:4bwxkkA3AAwyymVwXjxz0F
#     Getting uri for album The Stick Up Kid
#     Getting uri for album Big Noyd Hip Hop Instrumental, Vol. 1
#     Getting uri for album Queens Chronicle
#     Getting uri for album Illustrious
#     Getting uri for album Street Kings
# ======110======
#     Getting uri for artist Big Pokey
# Getting albums for Big Pokey: spotify:artist:1J6iGa2TNBDCrJzjsnI1a8
#     Getting uri for album Flow Masters Volume 1 : The Blast Off
#     Getting uri for album Tha Collabo
#     Getting uri for album The Hardest Pit In The Litter
#     Getting uri for album The Best Of Pt. 1 & Pt. 2
#     Getting uri for album Flow Masters Volume I: Tha Blast-Off
#     Getting uri for album Da Sky's Da Limit
#     Getting uri for album The Best Of II : 8ighted & Chopped
#     Getting uri for album Tha Collabo - Wreckshop Wolfpack
#     Getting uri for album Tha Collabo: The Wreckshop Wolfpack
#     Getting uri for album A Bad Azz Mix Tape III: Slowed & Chopped
#     Getting uri for album Hardest Pit In The Litter
#     Getting uri for album D Game 2000 : Chopped and Screwed
#     Getting uri for album On Another Note
#     Getting uri for album Evacuation Notice
#     Getting uri for album Hardest Pit in the Litter
#     Getting uri for album D Game 2000
#     Getting uri for album D'Game 2000
# ERROR: Unable to find album info for D'Game 2000
# ======111======
#     Getting uri for artist Big Pooh
# Getting albums for Big Pooh: spotify:artist:2hfa22hIjNd79uMZlWb0UF
#     Getting uri for album Alwayz Talkin Shit
#     Getting uri for album The Delightful Bars (North American Pie Version)
#     Getting uri for album Good Day, Bad Day
# ======112======
#     Getting uri for artist Big Pun
# Getting albums for Big Pun: spotify:artist:2Xu7q46Hf02xOoEIm4E1Qs
#     Getting uri for album Bronx Legends Never Die
#     Getting uri for album Capital Punishment (Explicit Version)
#     Getting uri for album Capital Punishment
#     Getting uri for album Yeah Baby
#     Getting uri for album Endangered Species
# ======113======
#     Getting uri for artist Big Reese
# Getting albums for Big Reese: spotify:artist:4fO6xCaRZ2hTFkr23ZrmIn
#     Getting uri for album Street Seed, Vol. 1
#     Getting uri for album Street Seed, Vol. 2
# ======114======
#     Getting uri for artist Big Scoob
# Getting albums for Big Scoob: spotify:artist:1PnsxAfjwnxNODAaKTu8VO
#     Getting uri for album H.O.G.
#     Getting uri for album Duality
#     Getting uri for album Damn Fool
# ======115======
#     Getting uri for artist Big Smo
# Getting albums for Big Smo: spotify:artist:7eRXja3QOjiMWRgkd5dYwo
#     Getting uri for album American Made
#     Getting uri for album The True South
#     Getting uri for album We the People
#     Getting uri for album The Audio Biography
#     Getting uri for album Special Reserve
#     Getting uri for album Kuntry Livin'
# ======116======
#     Getting uri for artist Big Sean
# Getting albums for Big Sean: spotify:artist:0c173mlxpT3dSFRgMO8XPh
#     Getting uri for album Good Music Chicago
# ERROR: Unable to find album info for Good Music Chicago
#     Getting uri for album Finally Famous
#     Getting uri for album Double Or Nothing (& Metro Boomin)
#     Getting uri for album Dark Sky Paradise (Deluxe)
#     Getting uri for album Dark Sky Paradise
#     Getting uri for album Hall Of Fame
#     Getting uri for album Hall Of Fame (Deluxe)
#     Getting uri for album Finally Famous (Deluxe)
#     Getting uri for album I Decided.
# ======117======
#     Getting uri for artist Big Shaq
# Getting albums for Big Shaq: spotify:artist:7mnAzEmgquhrVtGob81SmO
# ======118======
#     Getting uri for artist Big Shug
# Getting albums for Big Shug: spotify:artist:30G8Jlp6mw5RTEEzMndIZL
#     Getting uri for album Street Champ
#     Getting uri for album Never Say Die
#     Getting uri for album Other Side Of The Game
#     Getting uri for album Triple OGzus
#     Getting uri for album I. M. 4-Eva
#     Getting uri for album Who's Hard
# ERROR: Unable to find album info for Who's Hard
# ======119======
#     Getting uri for artist Big Syke
# Getting albums for Big Syke: spotify:artist:5J32qSlWzKCdcL31B8wglv
#     Getting uri for album Soldiers on Soil
#     Getting uri for album Street Commando
#     Getting uri for album Big Syke
#     Getting uri for album Big Syke Daddy
# ======120======
#     Getting uri for artist Bigg D
# Getting albums for Bigg D: spotify:artist:1yo6xM04b0DJlskqmZp395
# ======121======
#     Getting uri for artist Billy Woods
# Getting albums for Billy Woods: spotify:artist:40oHXuWk9TeViDthyHPALL
# ======122======
#     Getting uri for artist Birdman
# Getting albums for Birdman: spotify:artist:35sCXuy5gN6Or69rZ9vqBs
#     Getting uri for album Like Father Like Son
#     Getting uri for album Like Father Like Son (Edited Version)
# ERROR: Unable to find album info for Like Father Like Son (Edited Version)
#     Getting uri for album Pricele$$ (Deluxe)
#     Getting uri for album Fast Money
#     Getting uri for album Pricele$$
#     Getting uri for album Pricele$$ (UK Deluxe Edition Explicit)
# ERROR: Unable to find album info for Pricele$$ (UK Deluxe Edition Explicit)
#     Getting uri for album Lost At Sea 2
#     Getting uri for album 5 * Stunna
#     Getting uri for album Lost At Sea
#     Getting uri for album Fast Money Chopped and Screwed
# ======123======
#     Getting uri for artist Bishop Nehru
# Getting albums for Bishop Nehru: spotify:artist:1b5fazYV5ecKkQHKTlwLG8
#     Getting uri for album Nehruvia
#     Getting uri for album Elevators: Act I & II
#     Getting uri for album Strictly Flowz
#     Getting uri for album Emperor Nehru's New Groove
#     Getting uri for album Nehruvia: The Nehruvian
#     Getting uri for album Magic 19
# ======124======
#     Getting uri for artist Biz Markie
# Getting albums for Biz Markie: spotify:artist:22282KfMxDo2PMjnBc82I4
#     Getting uri for album Weekend Warrior
# ======125======
#     Getting uri for artist Bizarre
# Getting albums for Bizarre: spotify:artist:2TSvMFHlguDI495vujOAys
#     Getting uri for album Blue Cheese & Coney Island
#     Getting uri for album Lace Blunts
# ...
#     Getting uri for album My Own
# ERROR: Unable to find album info for My Own
#     Getting uri for album Preserved
#     Getting uri for album Carleone's Vintage
# ERROR: Unable to find album info for Carleone's Vintage
#     Getting uri for album Rise Thru Da Ranks
# ======1270======
#     Getting uri for artist Young Buck
# Getting albums for Young Buck: spotify:artist:4pr7J7wzgObkE3DD3Izi7q
#     Getting uri for album 10 Street Commandments
#     Getting uri for album The Natural 2 & The Rehab (Deluxe Edition)
#     Getting uri for album Before the Beast
#     Getting uri for album 10 Plugs
#     Getting uri for album 10 Toes Down
#     Getting uri for album 10 Politics
#     Getting uri for album 10 Plugs (Chopnotslop Remix)
#     Getting uri for album Back on My Buck Shit
#     Getting uri for album 10 Pints (Chopnotslop Remix)
#     Getting uri for album 10 Street Commandments (Chopnotslop Remix)
#     Getting uri for album 10 Bullets
#     Getting uri for album The Rehab
# ERROR: Unable to find album info for The Rehab
#     Getting uri for album 10 Felonies
#     Getting uri for album 10 Bricks
#     Getting uri for album Buck Fifty
#     Getting uri for album 10 Bodies
#     Getting uri for album 10 Pints
#     Getting uri for album Greatest Hits, Vol. 1
#     Getting uri for album 10 Toes Down (Chopnotslop Remix)
#     Getting uri for album Gas 2 - Gangsta & Street 2
# ======1271======
#     Getting uri for artist Young Chop
# Getting albums for Young Chop: spotify:artist:5L0n62BVUljSzKMLyMaFHR
#     Getting uri for album Life of a Boss
#     Getting uri for album King Chop
#     Getting uri for album King100jame$
#     Getting uri for album Fat Gang
#     Getting uri for album Finally Rich Too
#     Getting uri for album Let Em Know
#     Getting uri for album King Chop 2
#     Getting uri for album Still
# ERROR: Unable to find album info for Still
#     Getting uri for album 8417
#     Getting uri for album Precious
# ======1272======
#     Getting uri for artist Young Chris
# Getting albums for Young Chris: spotify:artist:5IYKSQZErXLpHp74EIIHp1
#     Getting uri for album Life Off The Roc
#     Getting uri for album Young Christmas
#     Getting uri for album Now or Never
#     Getting uri for album Network 3
#     Getting uri for album Politically Incorrect
#     Getting uri for album The Network 4
#     Getting uri for album The Network 5
#     Getting uri for album The Network 2
#     Getting uri for album The Network
#     Getting uri for album Killadelphia
#     Getting uri for album The Re-Introduction
#     Getting uri for album The Revival
#     Getting uri for album Hired Gun
#     Getting uri for album Campaign for Change
#     Getting uri for album Young Gunna
#     Getting uri for album Patiently Waiting Vol. 1
# ======1273======
#     Getting uri for artist Young Dolph
# Getting albums for Young Dolph: spotify:artist:3HiuzBlSW7pGDXlSFMhO2g
#     Getting uri for album 16 Zips
#     Getting uri for album Role Model
#     Getting uri for album Bulletproof
#     Getting uri for album Gelato
#     Getting uri for album East Atlanta Memphis
#     Getting uri for album 16
#     Getting uri for album High Class Street Music 4: American Gangster
#     Getting uri for album Thinking Out Loud
#     Getting uri for album Bosses & Shooters
#     Getting uri for album Tracking Numbers
#     Getting uri for album High Class Street Music 5: The Plug Best Friend
#     Getting uri for album King of Memphis
#     Getting uri for album Rich Crack Baby
#     Getting uri for album BagMen
#     Getting uri for album Shittin On The Industry
#     Getting uri for album Felix Brothers
# ======1274======
#     Getting uri for artist Young Dre the Truth
# Getting albums for Young Dre the Truth: None
# ====ERROR 1274====
# ======1275======
#     Getting uri for artist Young Dro
# Getting albums for Young Dro: spotify:artist:3ZooCJzNMTLpmJaIRUEorI
#     Getting uri for album Boot Up
#     Getting uri for album Da' Real Atlanta
#     Getting uri for album Day Two
#     Getting uri for album Hell Cat
#     Getting uri for album Phoenix
#     Getting uri for album Dro Street
#     Getting uri for album Polo Dro
#     Getting uri for album High Times
#     Getting uri for album We Outchea
#     Getting uri for album Da Reality Show
#     Getting uri for album Purple Label
#     Getting uri for album Equestrian Dro
#     Getting uri for album Black Label
# ERROR: Unable to find album info for Black Label
#     Getting uri for album Day 3
#     Getting uri for album Black Boy Swag, White Boy Tags
#     Getting uri for album Don Cannon & Young Dro Present R.I.P.
#     Getting uri for album Ralph Lauren Reefa
#     Getting uri for album Day One
# ERROR: Unable to find album info for Day One
#     Getting uri for album Drocabulary
# ======1276======
#     Getting uri for artist Young Greatness
# Getting albums for Young Greatness: spotify:artist:6eUSUma6IbsuvfAs9c0Kti
#     Getting uri for album Seven (VII)
#     Getting uri for album I Tried to Tell 'Em
#     Getting uri for album Bloody Summer
#     Getting uri for album Dollar For Hate
#     Getting uri for album I Tried To Tell Em 2
# ======1277======
#     Getting uri for artist Young Jeezy
# Getting albums for Young Jeezy: None
# ====ERROR 1277====
# ======1278======
#     Getting uri for artist Young M.A
# Getting albums for Young M.A: spotify:artist:7LvoDJUNGnOrPdGRzVtOJ9
#     Getting uri for album Herstory
# ======1279======
#     Getting uri for artist Young Maylay
# Getting albums for Young Maylay: spotify:artist:58zzaIQ8XVObJml8da0b2e
#     Getting uri for album San Andreas Original Mixtape
#     Getting uri for album The Real Coast Guard
# ======1280======
#     Getting uri for artist Young MC
# Getting albums for Young MC: spotify:artist:5n30a5V4ftXNMHCHChmK2h
#     Getting uri for album Stone Cold Rhymin'
#     Getting uri for album B-sides Demos & Remixes
#     Getting uri for album Adrenaline Flow
#     Getting uri for album Stone Cold Rhymin' (Deluxe Edition)
#     Getting uri for album Engage The Enzyme
#     Getting uri for album Relentless
#     Getting uri for album Ain't Goin' Out Like That
# ERROR: Unable to find album info for Ain't Goin' Out Like That
# ======1281======
#     Getting uri for artist Young Noble
# Getting albums for Young Noble: spotify:artist:58G1dVGEODhaSBjj2vJJvS
#     Getting uri for album Jerzey Mob Presents: "Young Noble"- Noble Justice (The Lost Songs)
#     Getting uri for album Son of God
#     Getting uri for album Noble Justice
#     Getting uri for album Noble Justice: The Lost Songs
#     Getting uri for album Powerful
#     Getting uri for album The Year of the Underdogz
#     Getting uri for album The Year Of The Underdogz
#     Getting uri for album The Code
#     Getting uri for album For My People
#     Getting uri for album Outlaw Rydahz
#     Getting uri for album Fast Life
# ======1282======
#     Getting uri for artist Young Scooter
# Getting albums for Young Scooter: spotify:artist:4cmA2QDPdzh8W2ytpyUGes
#     Getting uri for album Jugg King
#     Getting uri for album Fast Lane Juugin
#     Getting uri for album 80's Baby
# ERROR: Unable to find album info for 80's Baby
#     Getting uri for album Trippple Cross
#     Getting uri for album No Mo Struggle
#     Getting uri for album The Dream Team
#     Getting uri for album Free Bricks 2
#     Getting uri for album Married To The Streets
#     Getting uri for album Juggathon
# ERROR: Unable to find album info for Juggathon
# ======1283======
#     Getting uri for artist Young Thug
# Getting albums for Young Thug: spotify:artist:50co4Is1HCEo8bhOyUWKpn
#     Getting uri for album Slime Season 3
#     Getting uri for album I Came from Nothing 2
#     Getting uri for album Slime Language
#     Getting uri for album RG2
# ERROR: Unable to find album info for RG2
#     Getting uri for album I'm Up
# ERROR: Unable to find album info for I'm Up
#     Getting uri for album 1017 Thug
#     Getting uri for album MigoThuggin
# ERROR: Unable to find album info for MigoThuggin
#     Getting uri for album Young Thugger Mane La Flare
#     Getting uri for album SUPER SLIMEY
#     Getting uri for album Ready for War
#     Getting uri for album Beautiful Thugger Girls
#     Getting uri for album Street Is Watching (The Mix-Tape)
# ERROR: Unable to find album info for Street Is Watching (The Mix-Tape)
#     Getting uri for album JEFFERY
#     Getting uri for album Brick Sqaud
#     Getting uri for album Barter 6
# ======1284======
#     Getting uri for artist YoungBoy Never Broke Again
# Getting albums for YoungBoy Never Broke Again: spotify:artist:7wlFDEWiM5OoIAt8RSli8b
#     Getting uri for album Until Death Call My Name
#     Getting uri for album Until Death Call My Name Reloaded
#     Getting uri for album Before I Go Reloaded
#     Getting uri for album Mind Of A Menace 3 Reloaded
#     Getting uri for album 4Respect 4Freedom 4Loyalty 4WhatImportant
#     Getting uri for album Master The Day Of Judgement
#     Getting uri for album Decided
#     Getting uri for album Fed Baby’s
#     Getting uri for album 38 Baby
#     Getting uri for album Ain't Too Long
# ERROR: Unable to find album info for Ain't Too Long
#     Getting uri for album AI YoungBoy
# ======1285======
#     Getting uri for artist Your Old Droog
# Getting albums for Your Old Droog: spotify:artist:20dRvQDfCTLJU0pgq13ZYp
#     Getting uri for album Your Old Droog
#     Getting uri for album PACKS
# ======1286======
#     Getting uri for artist Yubin
# Getting albums for Yubin: spotify:artist:3JUj7c2h5xkdOf0GJ07VWE
# ======1287======
#     Getting uri for artist Yukmouth
# Getting albums for Yukmouth: spotify:artist:0ndMofuAPmTktjONZv20JL
#     Getting uri for album Savages
#     Getting uri for album 18k - The Golden Era: Deluxe Edition
#     Getting uri for album Eye Candy (Platinum Edition)
#     Getting uri for album In Thugs We Trust V.2
#     Getting uri for album JJ Based on a Vill Story Two
#     Getting uri for album Eye Candy
#     Getting uri for album Yukmouth Presents: The Center Of Attention (Special Edition)
#     Getting uri for album 18k - The Golden Era: Disc 2
#     Getting uri for album Dragon Dynasty
#     Getting uri for album Lord Of War
#     Getting uri for album Half Baked
#     Getting uri for album The West Coast Don
#     Getting uri for album JJ Based on a Vill Story
#     Getting uri for album JJ Based on a Vill Story Three
#     Getting uri for album The Cream Team
#     Getting uri for album Million Dollar Mouth
#     Getting uri for album The Tonite Show with Yukmouth: Thuggin' & Mobbin'
#     Getting uri for album GAS (Grow And Sale)
#     Getting uri for album Free At Last
#     Getting uri for album 18k - The Golden Era: Disc 1
# ======1288======
#     Getting uri for artist Yung Berg
# Getting albums for Yung Berg: spotify:artist:0BrPKSAeplwezYR1T2DF9s
#     Getting uri for album Yungn
#     Getting uri for album Look What You Made Me
# ======1289======
#     Getting uri for artist Yung Joc
# Getting albums for Yung Joc: spotify:artist:23LbwefIODbyGdRbAz3urj
#     Getting uri for album I Know You See It
#     Getting uri for album New Joc City (Amended Version U.S. Version)
#     Getting uri for album New Joc City (Explicit Content U.S. Version)
#     Getting uri for album Hustlenomics
#     Getting uri for album New Joc City
# ERROR: Unable to find album info for New Joc City
# ======1290======
#     Getting uri for artist Yung L.A.
# Getting albums for Yung L.A.: spotify:artist:5xUMw9vaS567MBBjsoLslo
#     Getting uri for album Tryna Tell Ya
#     Getting uri for album Suntrust Leland
#     Getting uri for album Blue Bank Roll Vol.2
#     Getting uri for album Swayvor
#     Getting uri for album Blue Bank Roll Vol.1
#     Getting uri for album Crushin' The Block: DJ Dutty Laundry and The Senate DJs Present Yung LA
#     Getting uri for album Expensive Language 2
#     Getting uri for album Crush Da Block
#     Getting uri for album I Think I Can Sang
#     Getting uri for album Offset Shawty
# ======1291======
#     Getting uri for artist Yung Lean
# Getting albums for Yung Lean: spotify:artist:67lytN32YpUxiSeWlKfHJ3
#     Getting uri for album Frost God
#     Getting uri for album Unknown Death 2002
#     Getting uri for album Stranger
#     Getting uri for album Warlord (Deluxe)
#     Getting uri for album Poison Ivy
#     Getting uri for album Unknown Memory
# ======1292======
#     Getting uri for artist Yung Ro
# Getting albums for Yung Ro: spotify:artist:1mQWZPciU2mObkw2Fpgbxg
#     Getting uri for album Nobody
#     Getting uri for album 2Lifted
# ======1293======
#     Getting uri for artist Yung Wun
# Getting albums for Yung Wun: spotify:artist:32u2WZCxOqyacmU7hNtboY
#     Getting uri for album The Dirtiest Thirstiest
# ======1294======
#     Getting uri for artist Yung6ix
# Getting albums for Yung6ix: spotify:artist:1q2U0RJo12z8YmBfb1RwOt
#     Getting uri for album 6ix O' clock
#     Getting uri for album High Star
# ======1295======
#     Getting uri for artist YZ
# Getting albums for YZ: spotify:artist:7mQbdI0QaWJPgu8ffgtKa6
#     Getting uri for album Muad'Dib
# ERROR: Unable to find album info for Muad'Dib
#     Getting uri for album The Legend Of Floyd Jones
# ======1296======
#     Getting uri for artist Z-Ro
# Getting albums for Z-Ro: spotify:artist:6MrdwyCIKbpXmTKQBlG3uq
#     Getting uri for album Crack (Screwed)
#     Getting uri for album No Love Boulevard
#     Getting uri for album Heroin (Chopped and Screwed)
#     Getting uri for album Power
# ERROR: Unable to find album info for Power
#     Getting uri for album Melting the Crown
#     Getting uri for album Kings of the South (Screwed)
#     Getting uri for album Cocaine (Screwed)
#     Getting uri for album Codeine
#     Getting uri for album The Crown
# ERROR: Unable to find album info for The Crown
#     Getting uri for album I Found Me Volume 2 (The KMJ & Straight Profit Collection)
#     Getting uri for album A.B.N (Assholes by Nature)
#     Getting uri for album Greatest Hits (Screwed)
#     Getting uri for album I Found Me (The KMJ & Straight Profit Collection)
#     Getting uri for album Legendary
#     Getting uri for album Sadism
#     Getting uri for album Street Legends Part 2
#     Getting uri for album Drankin' & Drivin'
#     Getting uri for album Mo City Grey
#     Getting uri for album Look What You Did to Me
# ======1297======
#     Getting uri for artist Zack de la Rocha
# Getting albums for Zack de la Rocha: None
# ====ERROR 1297====
# ======1298======
#     Getting uri for artist Zaytoven
# Getting albums for Zaytoven: spotify:artist:1mceaxtjWdEmwoDVAlkC41
#     Getting uri for album Bricks and Bells 5
#     Getting uri for album Trapholizay
#     Getting uri for album Texas to Atlanta
#     Getting uri for album Zaytown Sorority, Vol. 2
#     Getting uri for album Zay 4 Tre
#     Getting uri for album The Brick House Boyz
#     Getting uri for album Zaytoven Presents: Trapping Made It Happen
#     Getting uri for album Zaytoven Radio 2
#     Getting uri for album 6toven
#     Getting uri for album Project Shit
#     Getting uri for album Bricks and Bells 1
#     Getting uri for album Gwap Talk
#     Getting uri for album Bricks and Bells 3
#     Getting uri for album Bricks and Bells 2
#     Getting uri for album Let the Trap Say Amen
#     Getting uri for album Bricks and Bells 4
#     Getting uri for album Where Would the Game Be Without Me 2
#     Getting uri for album Experience Hope with Zaytoven, Vol. 2
#     Getting uri for album "A"
# ERROR: Unable to find album info for "A"
# ======1299======
#     Getting uri for artist Zebra Katz
# Getting albums for Zebra Katz: spotify:artist:5Tz4zMiRWqiQVAymWZz99a
#     Getting uri for album Drklng
# ======1300======
#     Getting uri for artist Zelooperz
# Getting albums for Zelooperz: spotify:artist:5j93hwFBNo29RJMsWvtzj8
#     Getting uri for album A Piece of the Geto
#     Getting uri for album Help
#     Getting uri for album Bothic
# ======1301======
#     Getting uri for artist Zico
# Getting albums for Zico: spotify:artist:4XpUIb8uuNlIWVKmgKZXC0
# ======1302======
#     Getting uri for artist Zombie Juice
# Getting albums for Zombie Juice: spotify:artist:3yAXW26fnch5fOTDL1vvJR
# ======1303======
#     Getting uri for artist List of hip hop groups
# Getting albums for List of hip hop groups: None
# ====ERROR 1303====
# ======1304======
#     Getting uri for artist Lists of musicians
# Getting albums for Lists of musicians: None
# ====ERROR 1304====
# ======1305======
#     Getting uri for artist
# Getting albums for : None
# ====ERROR 1305====

# %%
def get_albums(artist):
    
    artist_id = get_uri(artist.decode('utf-8'), 'artist')
    albums = spotify.artist_albums(artist_id)
    
    # For some reason duplicates some albums. Wrap as a set
    return set([album['name'] for album in albums['items']])

# %%
def get_album_artists(album):
    album_id = get_uri(album.decode('utf-8'), 'album')
    tracks = spotify.album_tracks(album_id)
    
    return set([artist['name']  
            for track in tracks['items']
            for artist in track['artists']])

# %%
def get_collaborators(artist):
    
    albums = get_albums(artist)

    return {album:list(get_album_artists(album)) for album in albums}

# %%
# def get_aggr_album(album):
#     results = spotify.search(q='album:%s' % album, type='album')

#     tracks = spotify.album_tracks(album_id)

# %%
def get_album_tracks(album):
    album_id = get_uri(album.decode('utf-8'), 'album')
    

    tracks = spotify.album_tracks(album_id)
    
    return [track['name'] for track in tracks['items']]

# %%
def get_audio_feature_album(album): 
    
    return spotify.audio_features(track_ids)

# %%
# Relevant features from Spotify API:
# energy
# loudness
# tempo
# valence
def get_song_features(album, features):
    tracks = get_album_tracks(album)
    
    album_id = get_uri(album.decode('utf-8'), 'album')
    
    for feature in features:
