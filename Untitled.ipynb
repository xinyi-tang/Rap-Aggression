# %%
import os,re
import requests as rq
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
import lyricsgenius as genius
import urllib3
import unidecode # 3rd party
import string
from bs4 import BeautifulSoup

# %%
#rapgenius information
rap_genius_id = "_17NJOxR9_RGp1XTQ1Vl3O--bxYh-cSzcCwASKlr-Xlyj3vh2_BsdedBZLX6xgdt"
client_secret = "2wlydcjFiqOlSI5Zi65OeizvaWRx16xkkjIBfPkqZ9t1aFNNYTrjza8ny6xYlXdJQSP_vMzj6e20O7ORtjIIcQ"
client_access_token = "Uzv_tj6uOXE9_1eX2wCrOGi3j4JtmYcm1kVF-UmPcC5gJh1MQZKJLph4aFp9frFx"

# %%
# make rappers from data folder
def get_rappers():
    
    def validate(name):
        # checks if the name has a
        illegal_chars = "|?:^*\""

        for c in illegal_chars:
            if c == '|':
                if name.find(c) > 0:
                    name = name.split("|")[1]
            if c == "\"":
                if name.find(c) > 0:
                    name = name.replace(r'"','',2)
            else: 
                name = name.replace(c,'')
        return name
    
    with open("data/rappers.txt", "r", encoding='utf-8') as f:
        rappers = f.read()
        
    return [validate(rapper).strip() for rapper in rappers.split("\n")]
rappers = get_rappers()

# %%
def song_lyrics(artist, track_title):
    track_title = track_title.replace("&", "and").partition("(")[0].strip()
    def _process(text):
        # formats the url
        puncs = set(string.punctuation) - set("-")
        text = [''.join([c for c in s if c not in puncs]).lower() 
                  for s in unidecode.unidecode(text).split()]
        return text
        
    artist = "-".join(_process(artist)).capitalize()
    track_title = "-".join(_process(track_title))
    
    URL = fr"https://genius.com/{'-'.join([artist, track_title])}-lyrics"
    
    # request page to get markup
    page = rq.get(URL)
    html = BeautifulSoup(page.text, "html.parser")
    lyrics = html.find("div", class_="lyrics").get_text()

    lyrics = " ".join([line for line in lyrics.strip("\n").split("\n") if not line.startswith('[') and line != ""])
    
    return " ".join(_process(lyrics))

# %%
def retrieve_albums(artist):
    with open(f'data/albums/{artist}.txt', 'r', encoding='utf8') as f:
        info = eval(f.read())
    return info

# %%
def get_all_lyrics(artist):
    print(f"getting albums for {artist}")
    info = retrieve_albums(artist)
    
    albums = []
    for album in info:
        album_info = {}
        print("  "+album['name'])
        album_info['name'] = album['name']
        album_info['date'] = album['release_date']
        album_info['tracks'] = list()
        for track in album['tracks']:
            try:
                lyrics = song_lyrics(artist, track['track_title'])
            except:
                continue
            print(f"Song: {track['track_title']}")
            album_info['tracks'].append({'name':track['track_title'],
             'lyrics': lyrics})
        albums.append(album_info)
    return albums

# %%
rappers = rappers[660:]

# %%
errors = []
for r in rappers:
    print(f"done: {r}")
    with open(f"data/lyrics/{r}.txt", 'w', encoding='utf8') as f:
        try:
            f.write(str(get_all_lyrics(r)))
        except SyntaxError:
            errors.append(r)
            continue
# Out:
# done: Lil Baby
# getting albums for Lil Baby
#   Harder Than Hard
# Song: A-Town
# Song: My Dawg
# Song: Dates
# Song: My Drip
# Song: Minute
# Song: Life
# Song: Narcs
# Song: Ride Or Die
# Song: Stendo
# Song: Large
# Song: Pink Slip
# Song: Survive Da Motion
#   Perfect Timing
# Song: Minute
#   Too Hard
# Song: To The Top
# Song: Money
# Song: All Of A Sudden
# Song: Money Forever
# Song: Best Of Me
# Song: Ride My Wave
# Song: Hurry
# Song: Sum More
# Song: Going For It
# Song: Slow Mo
# Song: Trap Star
# Song: Eat Or Starve
# Song: Freestyle
# Song: Vision Clear
# Song: Dive In
# Song: Stick On Me
#   2 The Hard Way
#   Drip Harder
# Song: Deep End (Lil Baby & Gunna)
# Song: Close Friends (Lil Baby & Gunna)
#   Street Gossip
# Song: Global
# Song: Pure Cocaine
# Song: Crush A Lot
# Song: Time (feat. Meek Mill)
# Song: Ready (feat. Gunna)
# Song: Word On The Street
# Song: This Week
# Song: Anyway (feat. 2 Chainz & Gucci Mane)
# Song: No Friends (feat. Rylo Rodriguez)
# Song: Realist In It (feat. Gucci Mane & Offset)
# Song: Section 8 (feat. Young Thug)
# Song: Chastised
# Song: Dreams 2 Reality (feat. NoCap)
#   Harder Than Ever
# Song: Spazz
# Song: I’m Straight
# Song: Exotic
# Song: Leaked
# Song: Bank
# Song: Cash
# Song: Southside
# Song: Throwing Shade
# Song: First Class
# Song: Right Now
# Song: Life Goes On
# Song: Transporter
# Song: Fit In
# Song: Boss Bitch
# Song: Never Needed No Help
# done: Lil Bibby
# getting albums for Lil Bibby
#   Free Crack
# done: Lil Debbie
# getting albums for Lil Debbie
#   Homegrown
#   Debbie
# Song: Can't Sit Wit Us
# Song: Damn
# Song: Cake Up
# Song: F That
# Song: Whoop (feat. Starrah)
# Song: My Level
# Song: Queen
# Song: Okay
# Song: Run It
# Song: Tell Me (feat. Njomza)
# Song: Turn Em Out
# Song: Feel Good
# Song: I'm On
#   Young B!tch
# Song: Don't Hate
# Song: Fleek
# Song: Me and U
# Song: Trap Lust
# Song: Too Bad
# Song: Zonin
# Song: Boom (feat. Aliky)
# Song: Castle Bricks
# Song: Bay 2 LA
#   OG In My System
# Song: Straight
# Song: Summer
# Song: Gimmie That
# Song: I Get It
# Song: In My Zone
# Song: All We Need Is Love (feat. Stacy Barthe)
# Song: Real One (feat. Sonyae Elise)
# Song: Keep On Lookin
# Song: Bands Up
# Song: Stakin
# Song: Show You
#   In My Own Lane
# Song: Intro
# Song: Dboy Magic (feat: Bricc Baby)
# Song: Remember That
# Song: Loaded
# Song: Fuck It Up (feat: Bali Baby)
# Song: No Wings
# Song: Trippy
# Song: Work With That
# Song: Slaughter
# Song: Classic
#   California Sweetheart Pt. 2
# Song: On Sight (feat. Bricc Baby & Jay Owens)
# Song: Bay 2 LA
# Song: Parody
# Song: Killin'em
# Song: Wiggle
# Song: I Do My Thang
# Song: Buss It
# done: Lil Dicky
# getting albums for Lil Dicky
#   Professional Rapper
# Song: Professional Rapper (feat. Snoop Dogg)
# Song: Who Knew
# Song: Lemme Freak
# Song: White Crime
# Song: Molly (feat. Brendon Urie of Panic at the Disco)
# Song: Bruh...
# Song: Hannibal Interlude (feat. Hannibal Buress)
# Song: $ave Dat Money (feat. Fetty Wap & Rich Homie Quan)
# Song: Oh Well (feat. Jace of Two-9)
# Song: Personality (feat. T Pain)
# Song: Pillow Talking (feat. Brain)
# Song: Classic Male Pregame
# Song: The Antagonist
# Song: The Antagonist II
# Song: Truman
# done: Lil Durk
# getting albums for Lil Durk
#   Signed to the Streets 2
# Song: Ready for Em
# Song: Ten Four
# Song: War wit Us
# Song: Rumors
# Song: Don't Take It Personal
# Song: Party
# Song: I Made It
# Song: Don't Know Me
# Song: Feds Listenin
# Song: What You Do to Me
# Song: I Go
# Song: Lil Niggaz
# Song: Gas and Mud
# Song: Live It Up
# Song: Perfect Picture
# Song: Hell in My City
# Song: Ain't Did Shit
# Song: Fly High
#   Lil Durk 2X (Deluxe)
# Song: Check
# Song: LilDurk2x
# Song: Hated On Me
# Song: So What
# Song: She Just Wanna
# Song: Money Walk
# Song: Glock Up
# Song: Rich Nigga
# Song: True
# Song: Set It Off
# Song: Super Powers
# Song: My Beyoncé
# Song: Make It Back
#   300 Days 300 Nights
# Song: Intro
# Song: Make It Back
# Song: Waffle House
# Song: This Case
# Song: My Beyonce
# Song: On Em
# Song: Believe It or Not
# Song: Every Night
# Song: Spent Me
# Song: Words from Bump J
# Song: Jump Off
# Song: On My Soul
# Song: Nobody
# Song: Street Nigga
# Song: Mud
# Song: Drug Party
# Song: Ride 4 Me
#   Remember My Name (Deluxe)
# Song: 500 Homicides
# Song: Amber Alert
# Song: Like Me
# Song: Lord Don't Make Me Do It
# Song: Don't Judge Me
# Song: Tryna' Tryna'
# Song: Higher
# Song: Resume
# Song: What Your Life Like
# Song: Why Me
# Song: Remember My Name
#   Signed To The Streets 3
# Song: Treacherous
# Song: Don't Talk To Me (feat. Gunna)
# Song: Spin The Block (feat. Future)
# Song: Neighborhood Hero
# Song: 100 Grand (feat. Ty Dolla $ign & A Boogie wit da Hoodie)
# Song: Habit
# Song: Skrubs
# Song: Play With Us (feat. Kevin Gates)
# Song: Preach
# Song: India Pt. II
# Song: Spazz
# Song: Home Body (feat. Gunna & TK Kravitz)
# Song: Benihana (feat. Kodak Black)
# Song: I Know
# Song: Astronomical
# Song: Downfall (feat. Young Dolph & Lil Baby)
# Song: Did For The Streets
# Song: Is What It Is
# Song: Way More
# Song: Rockstar (feat. Lil Skies)
#   Just Cause Y'all Waited
# Song: Public Housing
# Song: Just Flow
# Song: When I Was Little
# Song: How I Know
# Song: Granny Crib
# Song: Breather
# Song: Home Body
# Song: Durkio Krazy
# Song: Instigator
# Song: My Bruddas
#   Remember My Name
# Song: 500 Homicides
# Song: Amber Alert
# Song: Like Me
# Song: Lord Don't Make Me Do It
# Song: Don't Judge Me
# Song: Tryna' Tryna'
# Song: Higher
# Song: Resume
# Song: What Your Life Like
# Song: Why Me
#   Signed to the Streets
# Song: Competition
# Song: Don't Understand Me
# Song: Bang Bros
# Song: 100 Rounds
# Song: Hittaz
# Song: Who Is This
# Song: Dis Ain't What U Want
# Song: Street Life
# Song: Oh My God
# Song: Introduce Me
# Song: One Night
# Song: Times
#   Life Ain't No Joke
# Song: Dem Niggaz
# Song: Right Here
# Song: Action
# Song: Mollygurl
# Song: I'm On
# Song: Rydah
# Song: Disappearing
# Song: Fuck Em
# Song: Days of our Lives
# Song: Animal
# Song: Everything All White
# Song: Life Ain't No Joke
#   Bloodas
#   They Forgot
# Song: Intro
# Song: They Forgot
# Song: Too Late
# Song: Hard Shit
# Song: Rico
# Song: Young Niggas
# Song: We Dem Niggas
# Song: Shooter2x
# Song: Back 2 Back
# Song: Victim
# Song: Rider Chick
# Song: Rich Forever
# Song: Street Life
#   Signed to the Streets 2.5
# Song: The Story 2.5
# Song: Don't Love (feat. Derez Deshon)
# Song: Make It Out
# Song: India
# Song: Too Raw
# Song: Basically Fr
# Song: Streets Want Me (feat. Moneybagg Yo)
# Song: Feel Good (feat. YFN Lucci)
# Song: True Colors
#   Love Songs for the Streets
# Song: No Choice
# Song: Pick Your Poison
# Song: Handouts
# Song: Lately
# Song: Better
# Song: Uzi
# Song: What If
# done: Lil Eazy-E
# getting albums for Lil Eazy-E
# done: Lil Flip
# getting albums for Lil Flip
# done: Lil Herb
# getting albums for Lil Herb
# done: Lil Jon
# getting albums for Lil Jon
#   Too Short Mixtapes Vol 1: Nation Riders
#   Crunk Rock
# Song: G Walk
# Song: On De Grind
# Song: Killas
# Song: Get In Get Out
# Song: Outta Your Mind
# Song: Ride Da D
# Song: Ms. Chocolate
# Song: Like A Stripper
# Song: Work It Out
# Song: Hey
#   We Still Crunk!
# Song: Bia' Bia'
# Song: Put Yo Hood Up
# Song: Move Bitch (feat. Youngbloodz and Three Six Mafia)
# Song: Bia' Bia'
#   Gangsta Grillz 9
#   Crunk Juice
# Song: What U Gon' Do (feat. Lil Scrappy)
# Song: Da Blow (feat. Jazze Pha, Pimpin Ken, Trillville)
# Song: Contract (feat. 8 Ball, MJG)
# Song: White Meat (feat. 8 Ball, MJG)
# Song: Lovers And Friends
# Song: One Night Stand
# Song: In Da Club
# Song: Grand Finale (feat. Bun B, Fat Joe, Ice Cube, Nas, T.I.)
#   Crunk Rock (Deluxe)
# Song: Fall Out
# Song: G Walk
# Song: On De Grind
# Song: Killas
# Song: Get In Get Out
# Song: Outta Your Mind
# Song: Ride Da D
# Song: Ms. Chocolate
# Song: Like A Stripper
# Song: Every Freakin Night
# Song: What A Night
# Song: Work It Out
# Song: Machuka
# Song: Hey
# done: Lil Mama
# getting albums for Lil Mama
#   VYP - Voice of the Young People
# Song: Intro
# Song: One Hit Wonder
# Song: Get Loose Request
# Song: Shawty Get Loose
# Song: Gotta Go Deeper Skit
# Song: Stand Up
# Song: L.I.F.E.
# Song: College
# Song: Emotional Rollercoasters Skit
# Song: Broken Pieces
# Song: Swim
# Song: Truly In Love
# Song: Look At My Life Skit
# Song: Make It Hot
# Song: Pick It Up
# done: Lil Peep
# getting albums for Lil Peep
#   Come Over When You're Sober, Pt. 2
# Song: Broken Smile (My All)
# Song: Runaway
# Song: Sex with My Ex
# Song: Cry Alone
# Song: Leanin'
# Song: 16 Lines
# Song: Life is Beautiful
# Song: Hate Me
# Song: IDGAF
# Song: White Girl
# Song: Fingers
#   Come Over When You're Sober, Pt. 1
# Song: Benz Truck (гелик)
# Song: Save That Shit
# Song: Awful Things
# Song: U Said
# Song: The Brightside
# Song: Problems
# done: Lil Phat
# getting albums for Lil Phat
#   No Love
#   Long Live Da Trill
#   The Leak
#   Still Trill
#   Living & Earning
#   Trap-A-Holics Present: Death Before Dishonor
# Song: Count My Money Backwards
#   DJ Khaled Presents: Life of a Yungsta
#   Pour Up
# Song: Victoria Secret
#   Long Live Da Trill 2
# Song: Count My Money Backwards
# Song: Victoria Secret
#   Trill 4 Life
#   Never Use a Pen Again
# done: Lil Pump
# getting albums for Lil Pump
#   Lil Pump
# Song: What U Sayin' (feat. Smokepurpp)
# Song: Gucci Gang
# Song: Smoke My Dope (feat. Smokepurpp)
# Song: Crazy
# Song: Back (feat. Lil Yachty)
# Song: D Rose
# Song: At the Door
# Song: Youngest Flexer (feat. Gucci Mane)
# Song: Foreign
# Song: Whitney (feat. Chief Keef)
# Song: Molly
# Song: Iced Out (feat. 2 Chainz)
# Song: Boss
# Song: Flex Like Ouu
# Song: Pinky Ring (feat. Smokepurpp & Rick Ross)
# done: Lil Reese
# getting albums for Lil Reese
#   Supa Savage
# Song: Supa Savage (Intro)
# Song: Team
# Song: Wassup (F*ck N*ggas) (feat. Fredo Santana & Lil Durk)
# Song: I Need That
# Song: What It Look Like (feat. Chief Keef)
# Song: We Won't Stop (feat. Chief Keef)
# Song: No Lackin (feat. Wale)
#   Supa Savage 2
# Song: All That Haten
# Song: Benji Chasin
# Song: Day 1
# Song: Seen or Saw
# Song: Somebody (feat. Lil Durk)
# Song: How Could I
# Song: Baby (feat. Young Thug)
# Song: Gang
# Song: Brazy (feat. Chief Keef)
# Song: You Know How We Play
# Song: That's What's Up
# Song: Ride (feat. Jim Jones & Young Scooter)
# Song: Change Up (feat. Lil Durk)
#   Better Days
#   GetBackGang
# Song: Gotta Be
# Song: Get Back
# Song: Get Hit
# Song: Fired Up
# Song: Ready 4 Real (feat. Tee Grizzley)
# Song: Freestyle
# Song: Here
# Song: Outro
#   The Savagery
# Song: Supa Savage (Intro)
# Song: Team
# Song: Wassup (F*ck N*ggas)
# Song: I Need That
# Song: What It Look Like (feat. Chief Keef)
# Song: We Won't Stop (feat. Chief Keef)
# Song: No Lackin (feat. Wale)
# Song: All That Haten
# Song: Benji Chasin
# Song: Day 1
# Song: Seen or Saw
# Song: Somebody (feat. Lil Durk)
# Song: How Could I
# Song: Baby (feat. Young Thug)
# Song: Gang
# Song: Brazy (feat. Chief Keef)
# Song: You Know How We Play
# Song: That's What's Up
# Song: Ride (feat. Jim Jones & Young Scooter)
# Song: Change Up (feat. Lil Durk)
#   300 DegreZz
# Song: Sum New
# Song: Some Out Nun (feat. Jadakiss)
# Song: Feed The Fam
# Song: Still Workin
# Song: Come Around
# Song: However
# Song: Mo Weed
# Song: Sets Droppin (feat. Benji300)
# Song: Jakes
# Song: Seen or Saw (feat. Rick Ross)
# done: Lil Ric
# getting albums for Lil Ric
#   I'm On It
#   The Thug Nut [On One]
#   Deep N Tha Game
#   Plugged In - Live from the Streets
#   Still Grindin’ Vol. 4
#   Wicked Streets
#   It's Like Armageddon
# Song: 4 Tha 4 Sho's
# done: Lil Ru
# getting albums for Lil Ru
#   21 & Up
#   Boobie Trap
#   Till' the Wheels Fall Off
# done: Lil Scrappy
# getting albums for Lil Scrappy
#   Prince of the South 2
#   ATL's Finest (Collector's Edition)
#   Live From ATL 1
#   Silence And Secrecy: Black Rag Gang
#   Gangsta Grillz 9
#   Prince of the South
#   Merlo's Way
#   Prince of the South 2
#   The Grustle
# Song: Face Off
# Song: No L's
# Song: The Mall
# Song: Helicopter
# Song: Secrets
# Song: Stay
# Song: Mr Cosbi
# Song: Bags
# Song: Already Wet
# Song: No Love
#   Silence & Secrecy: Black Rag Gang
#   Prince of the South 1 & 2 (Deluxe Edition)
#   Confident
#   Success and Failure & Prince of the South 2 (Deluxe Edition)
#   Prince of the South / Prince of the South 2 (2 for 1: Special Edition)
#   The Return of the Prince of the South
# Song: No Ls
# Song: Helicopter (feat. Rolls Royce Rizzy)
#   Lil Scrappy presents....Goodtimes Wit My Clique
#   Prince of the South / Atl's Finest (2 for 1: Special Edition)
#   Prince of the South & ATL's Finest (Deluxe Edition)
#   Silence & Secrecy: Black Rag Gang (Clean Album)
# done: Lil Skies
# getting albums for Lil Skies
#   Life of a Dark Rose
# Song: Welcome To The Rodeo
# Song: The Clique
# Song: Red Roses (feat. Landon Cube)
# Song: Lust
# Song: Cloudy Skies
# Song: Signs of Jealousy
# Song: Big Money
# Song: Tell My Haters
# Song: Boss Up
# Song: Garden
# Song: Lettuce Sandwich
# Song: Strictly Business
# Song: Kill4u
# Song: Nowadays (feat. Landon Cube)
# done: Lil Twist
# getting albums for Lil Twist
#   Anger Management
# done: Lil Uzi Vert
# getting albums for Lil Uzi Vert
#   Luv Is Rage
# Song: Safe House
# Song: Banned From TV
# Song: Super Saiyan
# Song: 7am
# Song: Yamborghini Dream (feat. Young Thug)
# Song: Right Now
# Song: Top
# Song: All My Chains
# Song: Belly
# Song: Enemies
# Song: Paradise
#   Luv Is Rage 2 (Deluxe)
# Song: Sauce It Up
# Song: No Sleep Leak
# Song: The Way Life Goes (feat. Oh Wonder)
# Song: For Real
# Song: Feelings Mutual
# Song: Neon Guts (feat. Pharrell Williams)
# Song: Early 20 Rager
# Song: UnFazed (feat. The Weeknd)
# Song: Pretty Mami
# Song: How To Talk
# Song: X
# Song: Malfunction
# Song: Dark Queen
# Song: XO TOUR Llif3
# Song: Skir Skirr
# Song: Loaded
# Song: Diamonds All On My Wrist
# Song: 20 Min
#   The Perfect LUV Tape
# Song: Do What I Want
# Song: Of Course We Ghetto Flowers (feat. Playboi Carti & Offset)
# Song: Money Mitch
# Song: I Can Drive
# Song: You're Lost
# Song: Erase Your Social
# Song: Ronda (Winners)
# Song: Seven Million (feat. Future)
#   Luv Is Rage 2
# Song: Sauce It Up
# Song: No Sleep Leak
# Song: The Way Life Goes (feat. Oh Wonder)
# Song: For Real
# Song: Feelings Mutual
# Song: Neon Guts (feat. Pharrell Williams)
# Song: Early 20 Rager
# Song: UnFazed (feat. The Weeknd)
# Song: Pretty Mami
# Song: How To Talk
# Song: X
# Song: Malfunction
# Song: Dark Queen
# Song: XO TOUR Llif3
#   Lil Uzi Vert Vs. The World
# Song: Canadian Goose
# Song: Hi Roller
# Song: Money Longer
# Song: Grab the Wheel
# Song: You Was Right
# Song: Baby Are You Home
# Song: Ps & Qs
# Song: Team Rocket
# Song: Scott and Ramona
# done: Lil Wayne
# getting albums for Lil Wayne
#   I Am Not A Human Being II (Deluxe)
# Song: IANAHB
# Song: Curtains
# Song: Days And Days
# Song: Gunwalk
# Song: No Worries
# Song: Back To You
# Song: Trigger Finger
# Song: Beat The Shit
# Song: Rich As Fuck
# Song: Trippy
# Song: Love Me
# Song: God Bless Amerika
# Song: Hello
# Song: Lay It Down
# Song: Hot Revolver
# Song: My Homies Still
#   Loosing Myself
#   Tha Carter V
# Song: I Love You Dwayne
# Song: Don't Cry (feat. XXXTENTACION)
# Song: Dedicate
# Song: Uproar
# Song: Let It Fly (feat. Travis Scott)
# Song: Can't Be Broken
# Song: Dark Side Of The Moon (feat. Nicki Minaj)
# Song: Mona Lisa (feat. Kendrick Lamar)
# Song: What About Me (feat. Sosamann)
# Song: Open Letter
# Song: Famous (feat. Reginae Carter)
# Song: Problems
# Song: Dope Niggaz (feat. Snoop Dogg)
# Song: Hittas
# Song: Took His Time
# Song: Open Safe
# Song: Start This Shit Off Right (feat. Ashanti & Mack Maine)
# Song: Demon
# Song: Mess
# Song: Dope New Gospel (feat. Nivea)
# Song: Perfect Strangers
# Song: Used 2
# Song: Let It All Work Out
#   I Am Not A Human Being II
# Song: IANAHB
# Song: Curtains
# Song: Days And Days
# Song: Gunwalk
# Song: No Worries
# Song: Back To You
# Song: Trigger Finger
# Song: Beat The Shit
# Song: Rich As Fuck
# Song: Trippy
# Song: Love Me
# Song: God Bless Amerika
# Song: Hello
#   Tha Carter IV (Deluxe)
# Song: Intro
# Song: Blunt Blowin
# Song: MegaMan
# Song: 6 Foot 7 Foot
# Song: Nightmares Of The Bottom
# Song: She Will
# Song: How To Hate
# Song: Interlude
# Song: John
# Song: Abortion
# Song: So Special
# Song: How To Love
# Song: President Carter
# Song: It's Good
# Song: Outro
# Song: I Like The View
# Song: Mirror
# Song: Two Shots
# done: Lil Wyte
# getting albums for Lil Wyte
#   Liquor
#   Phinally Phamous Chopped & Screwed
# Song: By 2 Da Bad Guy (feat. D.J. Paul) - Dragged & Chopped Remix
# Song: U.S. Soldier Boy (feat. Three 6 Mafia) - Dragged & Chopped Remix
# Song: Crazy (feat. Josey Scott of Saliva) - Dragged & Chopped Remix
# Song: Smoke My Dro (feat. Dirt Bag) - Dragged & Chopped Remix
#   No Filter
# Song: Break the Knob Off
# Song: One of Them Days (feat. Twiztid)
# Song: Band Plays On
# Song: Smoke Beer
#   The Bad Influence
# Song: All Stops
# Song: I Say Yes
# Song: Leanin' Off Dat Yurple
# Song: I Rep Mine
# Song: I'm Da Bad Influence
# Song: Oxy Cotton
# Song: Supply & Demand
# Song: George Bush
# Song: Get Gone
# Song: So Called Homies
# Song: That's What It Is
# Song: Maria
# Song: Outro
#   Doubt Me Now
# Song: Doubt Me Now
# Song: Blame It On Da Bay
# Song: We Ain't Playin'
# Song: Zero Tolerance
# Song: In Here
# Song: Players In Da Atmosphere
# Song: My Smokin' Song
# Song: I Know You Strapped
# Song: Good Dope
# Song: Com'n Yo Direction
# Song: Oxy Cotton
# Song: In The Streets
# Song: Drop It Off
# Song: Acid
# Song: Crash Da Club
# Song: Ten Toes Tall
# Song: Death & Life [Skit]
# Song: Homicidal, Suicidal
# Song: Get High To This
#   No Sick Days
# Song: House Party
# Song: Run Up (feat. La Chat)
# Song: SJGR
# Song: Space
# Song: It's 4: 20
#   The One And Only
# Song: The One And Only
# Song: I Got Dat Candy
# Song: That's What's Up
# Song: Talkin' Ain't Walkin'
# Song: Get High
# Song: It's On
# Song: Feelin' Real Pimpish (feat. Project Pat)
# Song: Get Wrong
# Song: Choppa On Da Back Seat (feat. Project Pat)
# Song: Gettin' Money Boy
# Song: Cake
# Song: Got'm Lookin
# Song: Suicide
# Song: Ghostin'
# Song: Do It Fluid
# Song: Gun Do Da Talkin'
# Song: Outro
#   No Filter 2
# Song: Demons
# Song: My Smoking Song (feat. B Real)
#   Still Doubted?
# Song: I Do It
# Song: Sold My Soul (feat. Pastor Troy)
# Song: All Kinds of Drugs (feat. Young Buck & Lil Will)
# Song: M.E.M.P.H.I.S. (feat. Miscellaneous & Al Kapone)
# Song: Welcome 2 the Gathering (feat. Lord Infamous & Liquid Assassin)
# Song: Lesson Learned
# Song: Money Train Gang
# Song: Money (feat. Miss Wyte, Partee & Project Pat)
# Song: Lost in My Zone
#   B.A.R. (Bay Area Representatives)
#   Doubt Me Now Dragged and Chopped
# Song: Doubt Me Now
# Song: Blame It On Da Bay
# Song: Zero Tolerance
# Song: In Here
# Song: Crash Da Club
# Song: Drop it Off
# Song: Get High To This
# Song: Acid
# Song: Good Dope
# Song: We Ain't Playin'
# Song: In The Streets
# Song: My Smokin' Song
# Song: Homicidal, Suicidal
# Song: Players In da Atmosphere
# Song: Oxycotton
#   No Filter (Clean Version)
# Song: Break the Knob Off (Clean)
# Song: One of Them Days (feat. Twiztid) (Clean)
# Song: Band Plays On (Clean)
# Song: Smoke Beer (Clean)
#   Drugs
#   Wytelytes
# Song: Break the Knob Off
# Song: Band Plays On
# Song: One of Them Days (feat. Twiztid)
# Song: House Party
# Song: Sjgr
# Song: Run Up (feat. La Chat)
# done: Lil Xan
# getting albums for Lil Xan
#   TOTAL XANARCHY
# Song: Who I Am
# Song: Wake Up
# Song: Tick Tock
# Song: Diamonds
# Song: The Man
# Song: Saved by the Bell
# Song: Moonlight
# Song: Shine Hard
# Song: Round Here
# Song: Basically
# Song: Deceived
# Song: Betrayed
# Song: Slingshot
# Song: Far
# done: Lil Yachty
# getting albums for Lil Yachty
#   Lil Boat 2
# Song: SELF MADE
# Song: BOOM!
# Song: OOPS
# Song: TALK TO ME NICE
# Song: GET MONEY BROS.
# Song: COUNT ME IN
# Song: she ready
# Song: love me forever
# Song: DAS CAP
# Song: POP OUT
# Song: NBAYOUNGBOAT
